# %%
# !pip install spacy-transformers
# Out:
# Collecting spacy-transformers
#   Downloading spacy_transformers-1.3.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: spacy<4.1.0,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from spacy-transformers) (3.8.5)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy-transformers) (2.0.2)
# Collecting transformers<4.50.0,>=3.4.0 (from spacy-transformers)
#   Downloading transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from spacy-transformers) (2.6.0+cu124)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from spacy-transformers) (2.5.1)
# Collecting spacy-alignments<1.0.0,>=0.7.2 (from spacy-transformers)
#   Downloading spacy_alignments-0.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (1.1.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (2.11.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<4.1.0,>=3.5.0->spacy-transformers) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->spacy-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->spacy-transformers) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (0.30.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers) (0.5.3)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2025.1.31)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.1.0,>=3.5.0->spacy-transformers) (0.1.2)
# Downloading spacy_transformers-1.3.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.2/756.2 kB 5.8 MB/s eta 0:00:00
# Downloading spacy_alignments-0.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.0/314.0 kB 17.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 74.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 72.2 MB/s eta 0:00:00
# Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 90.5 MB/s eta 0:00:00
# Installing collected packages: spacy-alignments, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, transformers, spacy-transformers
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.3
#     Uninstalling transformers-4.51.3:
#       Successfully uninstalled transformers-4.51.3
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 spacy-alignments-0.9.1 spacy-transformers-1.3.8 transformers-4.49.0

# %% [markdown]
# ## Training

# %%
# !python -m spacy train config.cfg --output ./balanced_NER_trained --gpu-id 0
# Out:
# ✔ Created output directory: balanced_NER_trained
# ℹ Saving to output directory: balanced_NER_trained
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# tokenizer_config.json: 100% 466/466 [00:00<00:00, 3.77MB/s]
# vocab.json: 100% 1.72M/1.72M [00:00<00:00, 6.88MB/s]
# merges.txt: 100% 1.38M/1.38M [00:00<00:00, 42.1MB/s]
# tokenizer.json: 100% 3.95M/3.95M [00:00<00:00, 26.3MB/s]
# special_tokens_map.json: 100% 239/239 [00:00<00:00, 1.86MB/s]
# config.json: 100% 682/682 [00:00<00:00, 4.13MB/s]
# 2025-04-21 14:34:56.692506: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745246097.032231    2419 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745246097.127756    2419 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-21 14:34:57.868070: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors: 100% 1.42G/1.42G [00:24<00:00, 57.8MB/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at benjamin/roberta-large-wechsel-ukrainian and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['transformer', 'ner']
# ℹ Initial learn rate: 1e-05
# E    #       LOSS TRANS...  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  -------------  --------  ------  ------  ------  ------
#   0       0         123.65    103.50    0.21    0.13    0.74    0.00
#   1     200      114229.25  37176.78   74.76   75.94   73.61    0.75
#   2     400        9501.97   7840.34   86.26   86.58   85.94    0.86
#   3     600        7358.34   4788.50   88.96   90.22   87.72    0.89
#   4     800        4111.24   3578.21   89.51   90.32   88.71    0.90
#   5    1000        2482.47   2733.65   90.02   89.37   90.69    0.90
#   6    1200        2365.79   2318.82   91.31   91.29   91.34    0.91
#   8    1400        1824.40   1972.53   90.72   90.66   90.79    0.91
#   9    1600        1400.21   1388.81   90.64   90.89   90.40    0.91
#  10    1800        1574.47   1287.20   91.34   91.55   91.14    0.91
#  11    2000        1259.88   1020.83   90.75   89.94   91.58    0.91
#  12    2200        1082.75    836.41   91.51   91.49   91.53    0.92
#  13    2400         778.66    732.40   91.45   90.54   92.38    0.91
#  14    2600         843.03    701.10   91.44   90.90   91.98    0.91
#  16    2800         993.00    666.81   91.71   92.54   90.89    0.92
#  17    3000         578.05    514.48   91.77   91.87   91.68    0.92
#  18    3200         852.65    508.59   92.08   93.25   90.94    0.92
#  19    3400         426.27    395.42   91.74   91.90   91.58    0.92
# ^C

# %%
# !zip -r balanced_NER_trained_21_04.zip ./balanced_NER_trained
# Out:
#   adding: balanced_NER_trained/ (stored 0%)
#   adding: balanced_NER_trained/model-last/ (stored 0%)
#   adding: balanced_NER_trained/model-last/vocab/ (stored 0%)
#   adding: balanced_NER_trained/model-last/vocab/key2row (stored 0%)
#   adding: balanced_NER_trained/model-last/vocab/strings.json (deflated 91%)
#   adding: balanced_NER_trained/model-last/vocab/vectors.cfg (stored 0%)
#   adding: balanced_NER_trained/model-last/vocab/vectors (deflated 45%)
#   adding: balanced_NER_trained/model-last/vocab/lookups.bin (stored 0%)
#   adding: balanced_NER_trained/model-last/config.cfg (deflated 61%)
#   adding: balanced_NER_trained/model-last/tokenizer (deflated 88%)
#   adding: balanced_NER_trained/model-last/ner/ (stored 0%)
#   adding: balanced_NER_trained/model-last/ner/moves (deflated 72%)
#   adding: balanced_NER_trained/model-last/ner/cfg (deflated 33%)
#   adding: balanced_NER_trained/model-last/ner/model (deflated 8%)
#   adding: balanced_NER_trained/model-last/transformer/ (stored 0%)
#   adding: balanced_NER_trained/model-last/transformer/cfg (stored 0%)
#   adding: balanced_NER_trained/model-last/transformer/model (deflated 7%)
#   adding: balanced_NER_trained/model-last/meta.json (deflated 67%)
#   adding: balanced_NER_trained/model-best/ (stored 0%)
#   adding: balanced_NER_trained/model-best/vocab/ (stored 0%)
#   adding: balanced_NER_trained/model-best/vocab/key2row (stored 0%)
#   adding: balanced_NER_trained/model-best/vocab/strings.json (deflated 91%)
#   adding: balanced_NER_trained/model-best/vocab/vectors.cfg (stored 0%)
#   adding: balanced_NER_trained/model-best/vocab/vectors (deflated 45%)
#   adding: balanced_NER_trained/model-best/vocab/lookups.bin (stored 0%)
#   adding: balanced_NER_trained/model-best/config.cfg (deflated 61%)
#   adding: balanced_NER_trained/model-best/tokenizer (deflated 88%)
#   adding: balanced_NER_trained/model-best/ner/ (stored 0%)
#   adding: balanced_NER_trained/model-best/ner/moves (deflated 72%)
#   adding: balanced_NER_trained/model-best/ner/cfg (deflated 33%)
#   adding: balanced_NER_trained/model-best/ner/model (deflated 8%)
#   adding: balanced_NER_trained/model-best/transformer/ (stored 0%)
#   adding: balanced_NER_trained/model-best/transformer/cfg (stored 0%)
#   adding: balanced_NER_trained/model-best/transformer/model (deflated 8%)
#   adding: balanced_NER_trained/model-best/meta.json (deflated 67%)

# %%
from google.colab import files
files.download("file.zip")

# %%
# !python -m spacy evaluate /content/balanced_NER_trained/model-best /content/test.spacy --output /content/balanced.json --gpu-id 0
# Out:
# ℹ Using GPU: 0
# 2025-04-21 16:28:58.390857: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745252938.423287   31158 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745252938.433310   31158 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-21 16:28:58.476494: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ================================== Results ==================================
#
# TOK     100.00
# NER P   91.31
# NER R   86.60
# NER F   88.89
# SPEED   1883
#
#
# =============================== NER (per type) ===============================
#
#               P       R       F
# JOB       82.51   68.43   74.81
# PERS      97.15   95.62   96.38
# LOC       92.42   88.36   90.35
# PCT      100.00   99.08   99.54
# PERIOD    78.80   71.43   74.94
# ORG       93.17   90.66   91.90
# DOC       57.89   48.89   53.01
# MISC      49.49   32.03   38.89
# QUANT     90.32   86.60   88.42
# DATE      92.86   87.69   90.20
# ART       69.34   79.60   74.12
# TIME      70.00   63.64   66.67
# MON       97.36   92.74   94.99
#
# ✔ Saved results to /content/balanced.json

# %% [markdown]
# # Evaluating

# %% [markdown]
# ## Balanced NER

# %%
# !python -m spacy evaluate /content/drive/MyDrive/filtered_balanced_ner /content/drive/MyDrive/spacy_files_for_ner/balanced_ner/test.spacy --output /content/drive/MyDrive/NER_evaluation_results/balanced_ner_results/balanced.json --gpu-id 0
# Out:
# ℹ Using GPU: 0
# 2025-04-22 10:39:08.372208: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745318348.653643    1171 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745318348.722018    1171 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-22 10:39:09.352323: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ================================== Results ==================================
#
# TOK     100.00
# NER P   91.31
# NER R   86.60
# NER F   88.89
# SPEED   1651
#
#
# =============================== NER (per type) ===============================
#
#               P       R       F
# JOB       82.51   68.43   74.81
# PERS      97.15   95.62   96.38
# LOC       92.42   88.36   90.35
# PCT      100.00   99.08   99.54
# PERIOD    78.80   71.43   74.94
# ORG       93.17   90.66   91.90
# DOC       57.89   48.89   53.01
# MISC      49.49   32.03   38.89
# QUANT     90.32   86.60   88.42
# DATE      92.86   87.69   90.20
# ART       69.34   79.60   74.12
# TIME      70.00   63.64   66.67
# MON       97.36   92.74   94.99
#
# ✔ Saved results to
# /content/drive/MyDrive/NER_evaluation_results/balanced_ner_results/balanced.json

# %%
# !python -m spacy evaluate /content/drive/MyDrive/filtered_balanced_ner /content/drive/MyDrive/spacy_files_for_ner/orig_ner/test.spacy --output /content/drive/MyDrive/NER_evaluation_results/balanced_ner_results/orig.json --gpu-id 0
# Out:
# ℹ Using GPU: 0
# 2025-04-22 10:45:54.345599: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745318754.377178    3080 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745318754.387561    3080 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-22 10:45:54.424901: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ================================== Results ==================================
#
# TOK     100.00
# NER P   90.89
# NER R   86.08
# NER F   88.42
# SPEED   1837
#
#
# =============================== NER (per type) ===============================
#
#               P       R       F
# LOC       92.19   88.02   90.06
# PCT      100.00   98.89   99.44
# JOB       75.05   59.06   66.10
# PERS      97.01   95.18   96.08
# PERIOD    80.25   70.27   74.93
# ORG       92.89   89.93   91.38
# DOC       63.64   52.50   57.53
# MISC      48.42   32.39   38.82
# QUANT     89.66   87.64   88.64
# DATE      92.65   88.02   90.28
# ART       70.52   79.75   74.85
# TIME      66.67   60.00   63.16
# MON       97.07   91.69   94.30
#
# ✔ Saved results to
# /content/drive/MyDrive/NER_evaluation_results/balanced_ner_results/orig.json

# %%
# !python -m spacy evaluate /content/drive/MyDrive/filtered_balanced_ner /content/drive/MyDrive/spacy_files_for_ner/swapped_ner/test.spacy --output /content/drive/MyDrive/NER_evaluation_results/balanced_ner_results/swapped.json --gpu-id 0
# Out:
# ℹ Using GPU: 0
# 2025-04-22 10:47:35.656580: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745318855.676272    3538 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745318855.682698    3538 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-22 10:47:35.706824: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ================================== Results ==================================
#
# TOK     100.00
# NER P   93.33
# NER R   89.16
# NER F   91.20
# SPEED   1618
#
#
# =============================== NER (per type) ===============================
#
#               P        R        F
# JOB       90.63    80.78    85.42
# PERS      98.60    98.88    98.74
# LOC       92.31    90.32    91.30
# QUANT    100.00    75.00    85.71
# DATE      94.19    88.04    91.01
# MISC      80.00    36.36    50.00
# ORG       95.70    93.56    94.62
# DOC       20.00    20.00    20.00
# TIME     100.00   100.00   100.00
# PERIOD    65.22    83.33    73.17
# ART       52.63    76.92    62.50
# PCT      100.00   100.00   100.00
# MON      100.00   100.00   100.00
#
# ✔ Saved results to
# /content/drive/MyDrive/NER_evaluation_results/balanced_ner_results/swapped.json

# %% [markdown]
# ## Original NER model

# %%
# !python -m spacy evaluate /content/drive/MyDrive/retrained_ner_origin /content/drive/MyDrive/spacy_files_for_ner/balanced_ner/test.spacy --output /content/drive/MyDrive/NER_evaluation_results/orig_ner_results/balanced.json --gpu-id 0
# Out:
# ℹ Using GPU: 0
# 2025-04-22 10:48:15.198232: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745318895.228753    3728 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745318895.240320    3728 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-22 10:48:15.278622: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ================================== Results ==================================
#
# TOK     100.00
# NER P   89.76
# NER R   86.97
# NER F   88.34
# SPEED   1858
#
#
# =============================== NER (per type) ===============================
#
#              P       R       F
# JOB      80.53   67.75   73.59
# PERS     96.58   97.00   96.79
# LOC      93.65   89.02   91.28
# PCT      96.43   99.08   97.74
# PERIOD   77.42   70.94   74.04
# ORG      91.34   91.19   91.26
# DOC      61.29   42.22   50.00
# MISC     36.59   29.41   32.61
# QUANT    81.31   89.69   85.29
# DATE     86.10   91.91   88.91
# ART      72.69   69.20   70.90
# TIME     60.00   54.55   57.14
# MON      95.34   91.34   93.30
#
# ✔ Saved results to
# /content/drive/MyDrive/NER_evaluation_results/orig_ner_results/balanced.json

# %%
# !python -m spacy evaluate /content/drive/MyDrive/retrained_ner_origin /content/drive/MyDrive/spacy_files_for_ner/orig_ner/test.spacy --output /content/drive/MyDrive/NER_evaluation_results/orig_ner_results/orig.json --gpu-id 0
# Out:
# ℹ Using GPU: 0
# 2025-04-22 10:53:28.945494: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745319208.974617    5080 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745319208.984980    5080 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-22 10:53:29.022756: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ================================== Results ==================================
#
# TOK     100.00
# NER P   89.12
# NER R   87.17
# NER F   88.13
# SPEED   1905
#
#
# =============================== NER (per type) ===============================
#
#              P       R       F
# LOC      93.27   88.14   90.63
# PCT      95.70   98.89   97.27
# JOB      74.39   65.45   69.64
# PERS     96.20   96.60   96.40
# PERIOD   76.92   70.27   73.45
# ORG      90.89   90.71   90.80
# DOC      64.29   45.00   52.94
# MISC     36.13   30.28   32.95
# QUANT    81.00   91.01   85.71
# DATE     85.32   91.62   88.35
# ART      73.87   69.20   71.46
# TIME     66.67   60.00   63.16
# MON      95.48   91.08   93.23
#
# ✔ Saved results to
# /content/drive/MyDrive/NER_evaluation_results/orig_ner_results/orig.json

# %%
# !python -m spacy evaluate /content/drive/MyDrive/retrained_ner_origin /content/drive/MyDrive/spacy_files_for_ner/swapped_ner/test.spacy --output /content/drive/MyDrive/NER_evaluation_results/orig_ner_results/swapped.json --gpu-id 0
# Out:
# ℹ Using GPU: 0
# 2025-04-22 10:50:01.213239: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745319001.233156    4205 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745319001.239728    4205 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-22 10:50:01.261975: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# ================================== Results ==================================
#
# TOK     100.00
# NER P   92.17
# NER R   85.81
# NER F   88.87
# SPEED   1580
#
#
# =============================== NER (per type) ===============================
#
#               P        R        F
# JOB       89.08    71.26    79.18
# PERS      98.60    98.60    98.60
# LOC       90.53    92.47    91.49
# QUANT     85.71    75.00    80.00
# DATE      92.47    93.48    92.97
# ORG       92.76    93.28    93.02
# MISC      33.33     9.09    14.29
# DOC       33.33    20.00    25.00
# TIME       0.00     0.00     0.00
# PERIOD    75.00    83.33    78.95
# ART       53.33    61.54    57.14
# PCT      100.00   100.00   100.00
# MON       96.97    96.97    96.97
#
# ✔ Saved results to
# /content/drive/MyDrive/NER_evaluation_results/orig_ner_results/swapped.json

# %% [markdown]
# ## HF repo

# %%
# !python -m spacy package /content/drive/MyDrive/filtered_balanced_ner ./ --build wheel --name ner_uk_gender_balanced --version 1.0.0
# Out:
# ⚠ Generating packages without the 'build' package is deprecated and
# will not be supported in the future. To install 'build': pip install build
# ℹ Building package artifacts: wheel
# 2025-04-22 10:50:42.073004: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745319042.092820    4373 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745319042.099390    4373 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-22 10:50:42.126198: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ✔ Including 2 package requirement(s) from meta and config
# spacy-transformers>=1.3.8,<1.4.0, spacy>=3.8.5,<3.9.0
# ✔ Loaded meta.json from file
# /content/drive/MyDrive/filtered_balanced_ner/meta.json
# ✔ Generated README.md from meta.json
# ✔ Successfully created package directory
# 'uk_ner_uk_gender_balanced-1.0.0'
# uk_ner_uk_gender_balanced-1.0.0
# /usr/bin/python3: No module named build
# ⚠ Creating wheel with 'python -m build' failed. Falling back to
# deprecated use of 'wheel' with 'python setup.py bdist_wheel'
# running bdist_wheel
# running build
# running build_py
# creating build/lib/uk_ner_uk_gender_balanced
# copying uk_ner_uk_gender_balanced/__init__.py -> build/lib/uk_ner_uk_gender_balanced
# creating build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0
# copying uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/README.md -> build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0
# copying uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/config.cfg -> build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0
# copying uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/tokenizer -> build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0
# copying uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/meta.json -> build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0
# creating build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab
# copying uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/key2row -> build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab
# copying uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/strings.json -> build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab
# copying uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/vectors.cfg -> build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab
# copying uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/vectors -> build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab
# copying uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/lookups.bin -> build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab
# creating build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner
# copying uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner/moves -> build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner
# copying uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner/cfg -> build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner
# copying uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner/model -> build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner
# creating build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/transformer
# copying uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/transformer/cfg -> build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/transformer
# copying uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/transformer/model -> build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/transformer
# copying uk_ner_uk_gender_balanced/meta.json -> build/lib/uk_ner_uk_gender_balanced
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/uk_ner_uk_gender_balanced
# creating build/bdist.linux-x86_64/wheel/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0
# creating build/bdist.linux-x86_64/wheel/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab
# copying build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/key2row -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab
# copying build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/strings.json -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab
# copying build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/vectors.cfg -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab
# copying build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/vectors -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab
# copying build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/lookups.bin -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab
# copying build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/README.md -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0
# copying build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/config.cfg -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0
# copying build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/tokenizer -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0
# creating build/bdist.linux-x86_64/wheel/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner
# copying build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner/moves -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner
# copying build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner/cfg -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner
# copying build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner/model -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner
# creating build/bdist.linux-x86_64/wheel/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/transformer
# copying build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/transformer/cfg -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/transformer
# copying build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/transformer/model -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/transformer
# copying build/lib/uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/meta.json -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0
# copying build/lib/uk_ner_uk_gender_balanced/meta.json -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced
# copying build/lib/uk_ner_uk_gender_balanced/__init__.py -> build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced
# running install_egg_info
# running egg_info
# creating uk_ner_uk_gender_balanced.egg-info
# writing uk_ner_uk_gender_balanced.egg-info/PKG-INFO
# writing dependency_links to uk_ner_uk_gender_balanced.egg-info/dependency_links.txt
# writing entry points to uk_ner_uk_gender_balanced.egg-info/entry_points.txt
# writing requirements to uk_ner_uk_gender_balanced.egg-info/requires.txt
# writing top-level names to uk_ner_uk_gender_balanced.egg-info/top_level.txt
# writing manifest file 'uk_ner_uk_gender_balanced.egg-info/SOURCES.txt'
# reading manifest file 'uk_ner_uk_gender_balanced.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'LICENSE'
# warning: no files found matching 'LICENSES_SOURCES'
# writing manifest file 'uk_ner_uk_gender_balanced.egg-info/SOURCES.txt'
# Copying uk_ner_uk_gender_balanced.egg-info to build/bdist.linux-x86_64/wheel/./uk_ner_uk_gender_balanced-1.0.0-py3.11.egg-info
# running install_scripts
# creating build/bdist.linux-x86_64/wheel/uk_ner_uk_gender_balanced-1.0.0.dist-info/WHEEL
# creating 'dist/uk_ner_uk_gender_balanced-1.0.0-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'uk_ner_uk_gender_balanced/__init__.py'
# adding 'uk_ner_uk_gender_balanced/meta.json'
# adding 'uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/README.md'
# adding 'uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/config.cfg'
# adding 'uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/meta.json'
# adding 'uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/tokenizer'
# adding 'uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner/cfg'
# adding 'uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner/model'
# adding 'uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/ner/moves'
# adding 'uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/transformer/cfg'
# adding 'uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/transformer/model'
# adding 'uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/key2row'
# adding 'uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/lookups.bin'
# adding 'uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/strings.json'
# adding 'uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/vectors'
# adding 'uk_ner_uk_gender_balanced/uk_ner_uk_gender_balanced-1.0.0/vocab/vectors.cfg'
# adding 'uk_ner_uk_gender_balanced-1.0.0.dist-info/METADATA'
# adding 'uk_ner_uk_gender_balanced-1.0.0.dist-info/WHEEL'
# adding 'uk_ner_uk_gender_balanced-1.0.0.dist-info/entry_points.txt'
# adding 'uk_ner_uk_gender_balanced-1.0.0.dist-info/top_level.txt'
# adding 'uk_ner_uk_gender_balanced-1.0.0.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# ✔ Successfully created binary wheel
# uk_ner_uk_gender_balanced-1.0.0/dist/uk_ner_uk_gender_balanced-1.0.0-py3-none-any.whl

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# The token `again_new_token` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `again_new_token`

# %%
# !huggingface-cli repo create uk_ner_gender-balanced --type model
# Out:
# git version 2.34.1
# git-lfs/3.0.2 (GitHub; linux amd64; go 1.18.1)
#
# You are about to create linndfors/uk_ner_gender-balanced
# Proceed? [Y/n] y
#
# Your repo now lives at:
#   https://huggingface.co/linndfors/uk_ner_gender-balanced
#
# You can clone it locally with the command below, and commit/push as usual.
#
#   git clone https://huggingface.co/linndfors/uk_ner_gender-balanced

# %%
from huggingface_hub import upload_folder

upload_folder(
    folder_path="/content/drive/MyDrive/filtered_balanced_ner",
    repo_id="linndfors/uk_ner_gender-balanced",
    path_in_repo="",
)
# Out:
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# lookups.bin:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# model:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# model:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/linndfors/uk_ner_gender-balanced/commit/aec4de537476e37efbad0ed142073e67a8331203', commit_message='Upload folder using huggingface_hub', commit_description='', oid='aec4de537476e37efbad0ed142073e67a8331203', pr_url=None, repo_url=RepoUrl('https://huggingface.co/linndfors/uk_ner_gender-balanced', endpoint='https://huggingface.co', repo_type='model', repo_id='linndfors/uk_ner_gender-balanced'), pr_revision=None, pr_num=None)

# %%
# !pip install https://huggingface.co/linndfors/uk_ner_gender-balanced/resolve/main/uk_ner_uk_gender_balanced-1.0.0-py3-none-any.whl
# Out:
# Collecting uk-ner-uk-gender-balanced==1.0.0
#   Downloading https://huggingface.co/linndfors/uk_ner_gender-balanced/resolve/main/uk_ner_uk_gender_balanced-1.0.0-py3-none-any.whl (1322.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 GB 882.7 kB/s eta 0:00:00
# Requirement already satisfied: spacy-transformers<1.4.0,>=1.3.8 in /usr/local/lib/python3.11/dist-packages (from uk-ner-uk-gender-balanced==1.0.0) (1.3.8)
# Requirement already satisfied: spacy<3.9.0,>=3.8.5 in /usr/local/lib/python3.11/dist-packages (from uk-ner-uk-gender-balanced==1.0.0) (3.8.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (2.11.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (3.5.0)
# Requirement already satisfied: transformers<4.50.0,>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (4.49.0)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (2.6.0+cu124)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (0.9.1)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (2025.1.31)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (0.1.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (0.30.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<4.50.0,>=3.4.0->spacy-transformers<1.4.0,>=1.3.8->uk-ner-uk-gender-balanced==1.0.0) (0.5.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9.0,>=3.8.5->uk-ner-uk-gender-balanced==1.0.0) (0.1.2)
# Installing collected packages: uk-ner-uk-gender-balanced
# Successfully installed uk-ner-uk-gender-balanced-1.0.0

# %%
import spacy
nlp = spacy.load("uk_ner_uk_gender_balanced")

# %%
doc = nlp("На вул. Липинського стояла президентка Оксана і розмовляла з протестувальниками")

# %%
doc.ents
# Out:
# (вул. Липинського, президентка, Оксана)
