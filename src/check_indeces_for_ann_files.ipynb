# %%
def check_ann_indices(txt_path, ann_path):
    with open(txt_path, "r", encoding="utf-8") as f:
        text = f.read()

    with open(ann_path, "r", encoding="utf-8") as f:
        annotations = f.readlines()

    has_errors = False

    for line in annotations:
        if not line.startswith("T"):
            continue  # skip non-entity lines
        parts = line.strip().split("\t")
        if len(parts) != 4:
            print(f"Invalid line format: {line}")
            continue

        tid, tag_info, inds, phrase = parts
        # tag_parts = tag_info.split()
        # if len(tag_parts) < 5:
        #     print(f"Invalid tag info: {tag_info}")
        #     continue

        label = phrase
        start = int(inds.split(" ")[0])
        end = int(inds.split(" ")[1])
        extracted = text[start:end]

        if extracted != phrase:
            has_errors = True
            print(f"❌ Mismatch in {tid} ({label}):")
            print(f"  Annotated: '{phrase}'")
            print(f"  Extracted : '{extracted}'")
            print(f"  Location  : {start}-{end}\n")
        else:
            print(extracted, phrase)

    if not has_errors:
        print("✅ All annotation spans match the text.")

# Example usage:

# %%
check_ann_indices("/Users/linndfors/study/diploma/ner_for_fem/data/v2.0-swapped/data/bruk/0ac5140eb732-swapped.txt", "/Users/linndfors/study/diploma/ner_for_fem/data/v2.0-swapped/data/bruk/0ac5140eb732-swapped.ann")
# Out:
# докторка докторка
# Анґер Анґер
# Марининими Марининими
# Докторки Докторки
# Олексій Олексій
# Аделя Аделя
# докторкою докторкою
# Анґер Анґер
# докторка докторка
# ✅ All annotation spans match the text.

# %%
import os

def check_all_annotations_in_dir(directory):
    files = os.listdir(directory)
    txt_files = [f for f in files if f.endswith(".txt")]

    for txt_file in txt_files:
        base_name = os.path.splitext(txt_file)[0]
        ann_file = base_name + ".ann"
        txt_path = os.path.join(directory, txt_file)
        ann_path = os.path.join(directory, ann_file)

        if not os.path.exists(ann_path):
            print(f"⚠️ Missing annotation file for {txt_file}")
            continue

        # print(f"\n📄 Checking: {txt_file} & {ann_file}")
        check_ann_indices(txt_path, ann_path)

def check_ann_indices(txt_path, ann_path):
    with open(txt_path, "r", encoding="utf-8") as f:
        text = f.read()

    with open(ann_path, "r", encoding="utf-8") as f:
        annotations = f.readlines()

    has_errors = False

    for line in annotations:
        if not line.startswith("T"):
            continue  # skip non-entity lines
        parts = line.strip().split("\t")
        if len(parts) != 5:
            print(txt_path)
            print(f"Invalid line format: {line}")
            continue

        tid, tag_info, start, end, phrase = parts
        start = int(start)
        end = int(end)
        # tag_parts = tag_info.split()
        # if len(tag_parts) < 5:
        #     print(f"Invalid tag info: {tag_info}")
        #     continue

        label = phrase
        extracted = text[start:end]

        if extracted != phrase:
            has_errors = True
            print(f"❌ Mismatch in {tid} ({label}):")
            print(f"  Annotated: '{phrase}'")
            print(f"  Extracted : '{extracted}'")
            print(f"  Location  : {start}-{end}\n")

    # if not has_errors:
    #     print("✅ All annotation spans match the text.")

# Example usage:

# %%
check_all_annotations_in_dir("/Users/linndfors/study/diploma/ner_for_fem/data/v2.0-swapped_filtering/data/bruk")
# Out:
# 3
# Invalid line format: T19	JOB	1017 1024 писарки
#
# 3
# Invalid line format: T1	JOB 41 51	мікологині
#
# 3
# Invalid line format: T2	DATE 170 178	1859 р .
#
# 3
# Invalid line format: T3	JOB 198 207	ботанічка
#
# 3
# Invalid line format: T4	JOB 211 221	мікологиня
#
# 3
# Invalid line format: T5	PERS 222 233	А . де Барі
#
# 3
# Invalid line format: T9	ORG	600 638 Інституту української мови НАН України

# %%
check_all_annotations_in_dir("/Users/linndfors/study/diploma/ner_for_fem/data/v2.0-swapped_filtering/data/ng")

# %%
import os
import re

def fix_ann_file(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        lines = f.readlines()

    fixed_lines = []
    for line in lines:
        # Match lines in the format: T# LABEL START END PHRASE
        parts = line.strip().split("\t")

        # print(parts)
        # print(len(parts))
        
        if len(parts) == 4:
            t, lab, inds, phr = parts
            # parts[2] is the start and end indices, e.g., "242 247"
            # indices = parts[2]
            start_ind, end_ind = inds.split(" ")
            # Replace space with tab between indices
            # parts[2] = indices.replace(" ", "\t")
            fixed_line = "\t".join([t, lab, start_ind, end_ind, phr])
            # print(fixed_line)
            fixed_lines.append(fixed_line)
        else:
            fixed_lines.append(line)

    with open(file_path, "w", encoding="utf-8") as f:
        for fixed_line in fixed_lines:
            f.write(fixed_line + "\n")

    print(f"✅ Fixed: {os.path.basename(file_path)}")

def fix_all_ann_files_in_dir(directory):
    for file_name in os.listdir(directory):
        if file_name.endswith(".ann"):
            fix_ann_file(os.path.join(directory, file_name))

# Example usage:
# fix_all_ann_files_in_dir("/path/to/your/ann_folder")

# %%
fix_all_ann_files_in_dir("/Users/linndfors/study/diploma/ner_for_fem/data/v2.0-swapped/data/ng")
# Out:
# ✅ Fixed: 989b35bbc2b6-swapped.ann
# ✅ Fixed: 5e33850771e3-swapped.ann
# ✅ Fixed: 1c48b2f37af3-swapped.ann
# ✅ Fixed: 0050229d8534-swapped.ann
# ✅ Fixed: 150446f83aa2-swapped.ann
# ✅ Fixed: 00edded01d7f-swapped.ann
# ✅ Fixed: f50037706d0a-swapped.ann
# ✅ Fixed: 6d47a8c4d755-swapped.ann
# ✅ Fixed: 5e407e3ddb68-swapped.ann
# ✅ Fixed: 0e5456794c26-swapped.ann
# ✅ Fixed: cc9eda5dc1f3-swapped.ann
# ✅ Fixed: ac13bf912fcb-swapped.ann
# ✅ Fixed: 432e298a1354-swapped.ann
# ✅ Fixed: 23fed9919583-swapped.ann
# ✅ Fixed: 17f81040ab50-swapped.ann
# ✅ Fixed: 176e63516fab-swapped.ann
# ✅ Fixed: c446d7d1cea2-swapped.ann
# ✅ Fixed: f62160cb3ef6-swapped.ann
# ✅ Fixed: 8e66b8ea5086-swapped.ann
# ✅ Fixed: f8ce14d569d1-swapped.ann
# ✅ Fixed: 4ea65724096f-swapped.ann
# ✅ Fixed: e2e03aba8da3-swapped.ann
# ✅ Fixed: fc3221dac69d-swapped.ann
# ✅ Fixed: 1e8b049462e1-swapped.ann
# ✅ Fixed: de4c2d20b24b-swapped.ann
# ✅ Fixed: 7982679365fb-swapped.ann
# ✅ Fixed: d81632a877d7-swapped.ann
# ✅ Fixed: d4a86a1591b4-swapped.ann
# ✅ Fixed: 1e9389b05e86-swapped.ann
# ✅ Fixed: bdb88360d4a8-swapped.ann
# ✅ Fixed: b3e92d56950f-swapped.ann
# ✅ Fixed: 798252fda0ab-swapped.ann
# ✅ Fixed: 18dbbac93012-swapped.ann
# ✅ Fixed: db4996034aa6-swapped.ann
# ✅ Fixed: 2d37a2344b1e-swapped.ann
# ✅ Fixed: 39c7437146fd-swapped.ann
# ✅ Fixed: 7248ab4edfe9-swapped.ann
# ✅ Fixed: e0c4e3168c81-swapped.ann
# ✅ Fixed: 1ce0dee84a4d-swapped.ann
# ✅ Fixed: 3d437460799f-swapped.ann
# ✅ Fixed: 9452af41a134-swapped.ann
# ✅ Fixed: c49d24717658-swapped.ann
# ✅ Fixed: 03b52358982b-swapped.ann
# ✅ Fixed: 39544dbbe184-swapped.ann
# ✅ Fixed: 1a15fc79575f-swapped.ann
# ✅ Fixed: 8936d7a04255-swapped.ann
# ✅ Fixed: 00b1a798bebf-swapped.ann
# ✅ Fixed: b9ea4aa52bae-swapped.ann
# ✅ Fixed: 7eae7aa310d7-swapped.ann
# ✅ Fixed: 9c264bd5a100-swapped.ann
# ✅ Fixed: fc5b5a35776f-swapped.ann
# ✅ Fixed: 872cdd84eee4-swapped.ann
# ✅ Fixed: 3e21f62b9a2f-swapped.ann
# ✅ Fixed: 4fa4b01c6204-swapped.ann
# ✅ Fixed: fe12a985f7cd-swapped.ann
# ✅ Fixed: 517bca22990a-swapped.ann
# ✅ Fixed: a56a7edf7859-swapped.ann
# ✅ Fixed: d84580a3bacf-swapped.ann
# ✅ Fixed: 05b89d1a90bf-swapped.ann
# ✅ Fixed: 5a43160b965d-swapped.ann
# ✅ Fixed: 0f0e96425eed-swapped.ann
# ✅ Fixed: 6920ac746f54-swapped.ann
# ✅ Fixed: 258d2fd0d2fe-swapped.ann
# ✅ Fixed: ba4d4c8da29b-swapped.ann
# ✅ Fixed: e0c33f29a3ae-swapped.ann
# ✅ Fixed: 2980d5c34788-swapped.ann
# ✅ Fixed: 67b6f23997c5-swapped.ann
# ✅ Fixed: a4eee55da896-swapped.ann
# ✅ Fixed: 8ae216cd6d99-swapped.ann
# ✅ Fixed: 5a4b4498fe83-swapped.ann
# ✅ Fixed: 12ca40b4ecac-swapped.ann
# ✅ Fixed: f5e3415a3653-swapped.ann
# ✅ Fixed: b060489eff8f-swapped.ann
# ✅ Fixed: 4f2aecdde4c8-swapped.ann
# ✅ Fixed: 76b9b07172fb-swapped.ann
# ✅ Fixed: 9835fd136cb4-swapped.ann
# ✅ Fixed: 76cfe1c0a0b6-swapped.ann
# ✅ Fixed: f2653a1e387d-swapped.ann
# ✅ Fixed: c9e6ab501a7e-swapped.ann
# ✅ Fixed: 0f9884d8a5e1-swapped.ann
# ✅ Fixed: c3156652dba3-swapped.ann
# ✅ Fixed: ba4204adf371-swapped.ann
# ✅ Fixed: 65a4cc6e3723-swapped.ann
# ✅ Fixed: 1c3533ec1df3-swapped.ann
# ✅ Fixed: 510661e4d39d-swapped.ann
# ✅ Fixed: e6f68e10e0e4-swapped.ann
# ✅ Fixed: 0e31947e4561-swapped.ann
# ✅ Fixed: 19a095d6ed15-swapped.ann
# ✅ Fixed: 73eb785ac9bb-swapped.ann
# ✅ Fixed: 35a759d5871f-swapped.ann
# ✅ Fixed: 8806c823dee8-swapped.ann
# ✅ Fixed: a6b3166e4d3b-swapped.ann
# ✅ Fixed: 1257e7421756-swapped.ann
# ✅ Fixed: 52a055482925-swapped.ann
# ✅ Fixed: a4bdacf739df-swapped.ann
# ✅ Fixed: 0e6b8eb14491-swapped.ann
# ✅ Fixed: 36aa8022709f-swapped.ann
# ✅ Fixed: bf276ac58f0f-swapped.ann
# ✅ Fixed: c8944932e85f-swapped.ann
# ✅ Fixed: 6350e46219ca-swapped.ann
# ✅ Fixed: 4ac82fdf4d4d-swapped.ann
# ✅ Fixed: e19e41e16752-swapped.ann
# ✅ Fixed: c650874a1e16-swapped.ann
# ✅ Fixed: 29ee46b3128e-swapped.ann
# ✅ Fixed: b2541ea8cb83-swapped.ann
# ✅ Fixed: b991b2d46f85-swapped.ann
# ✅ Fixed: 97c7987b8f9c-swapped.ann
# ✅ Fixed: bed0c1b62024-swapped.ann
# ✅ Fixed: 4de429586136-swapped.ann
# ✅ Fixed: f4119f5f8406-swapped.ann
# ✅ Fixed: 6b71dda907fe-swapped.ann
# ✅ Fixed: a9d2c035032d-swapped.ann
# ✅ Fixed: 104263660695-swapped.ann
# ✅ Fixed: fd7413336034-swapped.ann
# ✅ Fixed: 1adfefe0e695-swapped.ann
# ✅ Fixed: 7d19fba564ad-swapped.ann
# ✅ Fixed: f82ca27cb935-swapped.ann
# ✅ Fixed: 82e415f0dd48-swapped.ann
# ✅ Fixed: 02bebf42e010-swapped.ann
# ✅ Fixed: e37120a0aa66-swapped.ann
# ✅ Fixed: 9a51afb8d050-swapped.ann
# ✅ Fixed: 5f0dd24186aa-swapped.ann
# ✅ Fixed: 7f9631dbc39d-swapped.ann
# ✅ Fixed: 372677bde8c8-swapped.ann
# ✅ Fixed: c5930ba45ebe-swapped.ann
# ✅ Fixed: 605d2142ccad-swapped.ann
# ✅ Fixed: 46b3a16d4154-swapped.ann
# ✅ Fixed: 1044724b1e84-swapped.ann
# ✅ Fixed: d7e523681acc-swapped.ann
# ✅ Fixed: bd76ed4df58f-swapped.ann
# ✅ Fixed: 41cf54503fc6-swapped.ann
# ✅ Fixed: 521b5669bca6-swapped.ann
# ✅ Fixed: aeabc0bd5724-swapped.ann
# ✅ Fixed: b72e7e33e081-swapped.ann
# ✅ Fixed: ce52c670e720-swapped.ann
# ✅ Fixed: 16fb31bf76b8-swapped.ann
# ✅ Fixed: 9690987f7b71-swapped.ann
# ✅ Fixed: 45ce670b36e1-swapped.ann
# ✅ Fixed: 3fdf22393022-swapped.ann
# ✅ Fixed: c1ddc42c47fb-swapped.ann
# ✅ Fixed: 78153c6d7c59-swapped.ann
# ✅ Fixed: 4e486c879cf1-swapped.ann
# ✅ Fixed: 39c1d99f468f-swapped.ann
# ✅ Fixed: 06d7009e4925-swapped.ann
# ✅ Fixed: 19ebc4aa5eb5-swapped.ann
# ✅ Fixed: 037bb6843538-swapped.ann
# ✅ Fixed: 6f6281133248-swapped.ann
# ✅ Fixed: ca414599779c-swapped.ann
# ✅ Fixed: cdc9c08df7ac-swapped.ann
# ✅ Fixed: 07c51f631d18-swapped.ann
# ✅ Fixed: 7e6a2bdcfd1c-swapped.ann
# ✅ Fixed: d6ca19c4065e-swapped.ann
# ✅ Fixed: 4671f9337340-swapped.ann
# ✅ Fixed: 6ada9307320e-swapped.ann
# ✅ Fixed: 9893f2c9cae9-swapped.ann
# ✅ Fixed: 33b6963bc554-swapped.ann
# ✅ Fixed: 535022e2bdd2-swapped.ann
# ✅ Fixed: d15b83fd32bd-swapped.ann
# ✅ Fixed: fa2b54229991-swapped.ann
# ✅ Fixed: 3b570ac3116b-swapped.ann
# ✅ Fixed: 8098d69d861f-swapped.ann
# ✅ Fixed: 236f916f3d6f-swapped.ann
# ✅ Fixed: 7cf7a5aacb51-swapped.ann
# ✅ Fixed: 30856acf29fc-swapped.ann
# ✅ Fixed: 2850ba499aea-swapped.ann
# ✅ Fixed: 163e835b7aef-swapped.ann
# ✅ Fixed: 69dd300fd706-swapped.ann
# ✅ Fixed: 47713afd9490-swapped.ann
# ✅ Fixed: 348b96a54914-swapped.ann
# ✅ Fixed: 605667093f7b-swapped.ann
# ✅ Fixed: ab66959f7440-swapped.ann
# ✅ Fixed: 789ba2b89a05-swapped.ann
# ✅ Fixed: 937ae8974dd6-swapped.ann
# ✅ Fixed: 66f7109b4b72-swapped.ann
# ✅ Fixed: 5111063957b7-swapped.ann
# ✅ Fixed: cbf21c99c504-swapped.ann
# ✅ Fixed: 3eef4bd7fc75-swapped.ann
# ✅ Fixed: f5475c5dbfc9-swapped.ann
# ✅ Fixed: 2c14409069b7-swapped.ann
# ✅ Fixed: b0163b57e788-swapped.ann
# ✅ Fixed: 01cfbeca9827-swapped.ann
# ✅ Fixed: 996f3a16780e-swapped.ann
# ✅ Fixed: 357039d66ab7-swapped.ann
# ✅ Fixed: 1c3c6180ad96-swapped.ann
# ✅ Fixed: bf6104a5e8cc-swapped.ann
# ✅ Fixed: 63711262f9fb-swapped.ann
# ✅ Fixed: c2a04d86bfb8-swapped.ann
# ✅ Fixed: b859478153e4-swapped.ann
# ✅ Fixed: 26c531a355cc-swapped.ann
# ✅ Fixed: cffa0e3aa90f-swapped.ann
# ✅ Fixed: b4fe41ad2268-swapped.ann
# ✅ Fixed: 7ff7b6cfbbc2-swapped.ann
# ✅ Fixed: c09661af0a89-swapped.ann
# ✅ Fixed: d1d4639dbadd-swapped.ann
# ✅ Fixed: 7faf035614c1-swapped.ann
# ✅ Fixed: 08c0799d889a-swapped.ann
# ✅ Fixed: eed5beaf4033-swapped.ann
# ✅ Fixed: a04af354c8db-swapped.ann
# ✅ Fixed: 3dfca2b9b104-swapped.ann
# ✅ Fixed: e54ada2b9649-swapped.ann
# ✅ Fixed: 5de8e21df21b-swapped.ann
# ✅ Fixed: b217b90e209d-swapped.ann
# ✅ Fixed: 3e94fe6e9161-swapped.ann
# ✅ Fixed: 0f94c5cc63c3-swapped.ann
# ✅ Fixed: bf3f1e807703-swapped.ann
# ✅ Fixed: cb8dd5ea2542-swapped.ann
# ✅ Fixed: ac7d3bf88e39-swapped.ann
# ✅ Fixed: 7d59bb5fe9f5-swapped.ann
# ✅ Fixed: 290f12765b32-swapped.ann
# ✅ Fixed: 79ccf625bc94-swapped.ann
# ✅ Fixed: 540d36b4fe1c-swapped.ann
# ✅ Fixed: 25df43bd3fc5-swapped.ann
# ✅ Fixed: 386f07b6aca3-swapped.ann
# ✅ Fixed: 3aa7c6a81ddd-swapped.ann
# ✅ Fixed: 4bdc94abaa1c-swapped.ann
# ✅ Fixed: 883e1bd852d8-swapped.ann
# ✅ Fixed: 5658ff392f11-swapped.ann
# ✅ Fixed: d509463360e2-swapped.ann
# ✅ Fixed: 54a45ec4929b-swapped.ann
# ✅ Fixed: 860e4c9353fc-swapped.ann
# ✅ Fixed: e32c3effa79e-swapped.ann
# ✅ Fixed: 64d0d60bba23-swapped.ann
# ✅ Fixed: ab299615a1ce-swapped.ann
# ✅ Fixed: 5d3d7e0d5bae-swapped.ann
# ✅ Fixed: aae1500a7f12-swapped.ann
# ✅ Fixed: 5d7350e7d539-swapped.ann
# ✅ Fixed: 2ff4fbe3fcc4-swapped.ann
# ✅ Fixed: 3b285211209c-swapped.ann
# ✅ Fixed: 452ba42e97ec-swapped.ann
# ✅ Fixed: cf79fc17c020-swapped.ann
# ✅ Fixed: d084adea3ae8-swapped.ann
# ✅ Fixed: b645c9653d72-swapped.ann
# ✅ Fixed: 04b2cf6b449e-swapped.ann
# ✅ Fixed: bbc5330abbdc-swapped.ann
# ✅ Fixed: 86c78648f86f-swapped.ann
# ✅ Fixed: 16a112c13847-swapped.ann
# ✅ Fixed: 94c633b4d39a-swapped.ann
# ✅ Fixed: 3b4ea1813b99-swapped.ann
# ✅ Fixed: c97bff36f45a-swapped.ann
# ✅ Fixed: 7d5bd98c3363-swapped.ann
# ✅ Fixed: 61267204736d-swapped.ann
# ✅ Fixed: 8e1267225acc-swapped.ann
# ✅ Fixed: 59a9444d5c2d-swapped.ann
# ✅ Fixed: ff85f24f2204-swapped.ann
# ✅ Fixed: 816a89664813-swapped.ann
# ✅ Fixed: 87deabcc8f95-swapped.ann
# ✅ Fixed: 2d2e9cf66e5b-swapped.ann
# ✅ Fixed: 757fc6f23e18-swapped.ann
# ✅ Fixed: 1b68c2c76541-swapped.ann
# ✅ Fixed: 06826af4579d-swapped.ann
# ✅ Fixed: e96b3ae1908b-swapped.ann
# ✅ Fixed: f342f88df1c8-swapped.ann
# ✅ Fixed: 7ab185008967-swapped.ann
# ✅ Fixed: 369c3876ae3d-swapped.ann
# ✅ Fixed: 02634352df22-swapped.ann
# ✅ Fixed: 62127c82f7cd-swapped.ann
# ✅ Fixed: d080aa19c4bd-swapped.ann
# ✅ Fixed: a854e880d075-swapped.ann
# ✅ Fixed: c99d1ad0cc3c-swapped.ann
# ✅ Fixed: 09e1dccb8839-swapped.ann
# ✅ Fixed: 03d075bafb84-swapped.ann
# ✅ Fixed: cb7958ff386e-swapped.ann
# ✅ Fixed: 30933a298472-swapped.ann
# ✅ Fixed: 8c6db2873e45-swapped.ann
# ✅ Fixed: c07e05e53013-swapped.ann
# ✅ Fixed: 8f5d434373e2-swapped.ann
# ✅ Fixed: d13ee85bbf5c-swapped.ann
# ✅ Fixed: 003d28360166-swapped.ann
# ✅ Fixed: 8b3ec884f52d-swapped.ann
# ✅ Fixed: 5ae61df96054-swapped.ann
# ✅ Fixed: 64bbab373f73-swapped.ann
# ✅ Fixed: 315a7f9491ac-swapped.ann
# ✅ Fixed: 75e21fe4f3b7-swapped.ann
# ✅ Fixed: a767be7c3792-swapped.ann
