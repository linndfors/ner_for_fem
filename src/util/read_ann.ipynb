# %%
import pandas as pd
import os
import re

# %%
# !pip install pymorphy3
# !pip install pymorphy3-dicts-uk

# %% [markdown]
# # Extract JOB TITLES entities

# %%
def find_ann_files(directory):
    ann_files = []

    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".ann"):
                file_path = os.path.join(root, file)
                ann_files.append(file_path)

    return ann_files

# %%
def read_ann_files(directory):
    ann_files = find_ann_files(directory)
    job_title_entities = []

    for ann_file in ann_files:
        with open(ann_file, "r", encoding="utf-8") as ann_f:
            for ann_l in ann_f:
                ann_row = ann_l.split("\t")
                
                try: 
                    if ann_row[1] == 'JOB':
                        job_title_entities.append(ann_row[4].strip("\n"))
                except Exception as e:
                    continue
                    # print("Error with line:", ann_row)

    return job_title_entities

# %%
job_title_entities_bruk = read_ann_files('../ner_for_fem/data/bruk')
job_title_entities_ng = read_ann_files('../ner_for_fem/data/ng')

print("Number of job titles entities in bruk dataset:", len(job_title_entities_bruk))
print("Number of job titles entities in ng dataset:", len(job_title_entities_ng))
# Out:
# Number of job titles entities in bruk dataset: 638
# Number of job titles entities in ng dataset: 1344

# %%
job_title_entities_bruk
# Out:
# ['заступник',
#  'художника',
#  'лектори',
#  'режисером',
#  'народних депутатів',
#  'видавцями',
#  'голова',
#  'голова',
#  'тренери',
#  'науковець',
#  'фотографа',
#  'тележурналіст',
#  'викладачі-методисти',
#  'Доцент',
#  'викладачі',
#  'викладач',
#  'викладач',
#  'журналісти',
#  'священиком',
#  'священика',
#  'священика',
#  'співробітників',
#  'мол . наук . співробітника',
#  'програміста',
#  'редактор',
#  'пекар',
#  'охоронці',
#  'актриса',
#  'начальника',
#  'музейниками',
#  'священик',
#  'священик',
#  'панотця',
#  'кобзарі',
#  'Орнітологи',
#  'орнітологи',
#  'письменник',
#  'начальникові',
#  'геолог',
#  'військовим',
#  'позаштатний кореспондент',
#  'священиків',
#  'режисера',
#  'князь',
#  'поет-символіст',
#  'поет',
#  'поет',
#  'байкар',
#  'прозаїк',
#  'співець',
#  'поетів',
#  'письменники',
#  'психологів',
#  'дослідники',
#  'психологи',
#  'психологи',
#  'психолог',
#  'поетів',
#  'поетів',
#  'художник',
#  'психіатр',
#  'водія',
#  'доктор',
#  'голова',
#  'губернатор',
#  'нардеп',
#  'голові',
#  'депутатом',
#  'голови',
#  'керівник',
#  'голова',
#  'голову',
#  'офіцер',
#  'портьє',
#  'адміністратора',
#  'поет',
#  'драматург',
#  'письменниками',
#  'драматург',
#  'газетярів',
#  'підприємець',
#  'журналісти',
#  'журналісти',
#  'чиновників',
#  'журналістам',
#  'підприємців',
#  'журналісти',
#  'Чиновник',
#  'голови',
#  'редактора',
#  'журналіста',
#  'Голова',
#  'демографів',
#  'землероби',
#  'директор',
#  'директор',
#  'найманців',
#  'монахів',
#  'Жовніри',
#  'Жовніри',
#  'солдатів',
#  'жовніри',
#  'найманців',
#  'Кучер',
#  'Директором',
#  'шахтарям',
#  'голубівники',
#  'Судді',
#  'шахтар',
#  'письменник',
#  'мисливців',
#  'Письменник',
#  'письменник',
#  'письменника',
#  'сторожів',
#  'приватного детектива',
#  'письменника',
#  'Прокурор',
#  'ректор',
#  'військовослужбовців',
#  'очільник',
#  'Міністр оборони України',
#  'військовослужбовців',
#  'Міністр оборони України',
#  'військовослужбовець',
#  'Міністр оборони України',
#  'Міністра оборони України',
#  'президента',
#  'очільник',
#  'Президента',
#  'поліцаїв',
#  'хіміки',
#  'хімік',
#  'хіміка',
#  'хіміка',
#  'учених',
#  'хімік',
#  'вихователька',
#  'продавчиня',
#  'студентів',
#  'кандидата філологічних наук',
#  'інженера-програміста',
#  'кандидата філологічних наук',
#  'молодшого наукового співробітника',
#  'кандидата філологічних наук',
#  'доктор філологічних наук',
#  'професор',
#  'член-кореспондент',
#  'шефа',
#  'шеф',
#  'шеф',
#  'Шеф',
#  'Шеф',
#  'підмайстра',
#  'підмайстра',
#  'шеф',
#  'майстер',
#  'лікарів',
#  'лікаркою',
#  'інженер',
#  'інженер',
#  'начальник',
#  'одноосібним керівником',
#  'начальника',
#  'вчителя',
#  'королів',
#  'князів',
#  'король',
#  'педагогом',
#  'вчителька',
#  'вчителька',
#  'народний депутат',
#  'міського голови',
#  'начальника',
#  'Народний депутат',
#  'координатора',
#  'науковий співробітник',
#  'зоолог',
#  'слюсаря',
#  'викладачки',
#  'професора',
#  'депутатом',
#  'головою осередків',
#  'заступник голови',
#  'лікар',
#  'лікарка',
#  'секретар',
#  'секретарка',
#  'психолог',
#  'психологиня',
#  'мовознавиця',
#  'кандидатка філологічних наук',
#  'викладачка',
#  'голова',
#  'меценатів',
#  'депутати',
#  'журналіста',
#  'гастролерів',
#  'акторам',
#  'мовознавцем',
#  'комісара міліції',
#  'комісар',
#  'лісники',
#  'богословів',
#  'пастирю',
#  'пастир',
#  'пастирів',
#  'вчителька',
#  'будівельників',
#  'керівників',
#  'топ-менеджерів',
#  'заступник міністра',
#  'заступник міністра',
#  'академіком',
#  'режисери-постановники',
#  'співачка',
#  'дизайнерами',
#  'стилістів',
#  'візажистів',
#  'кутюр’є',
#  'міліціонера',
#  'міліціонер',
#  'учитель',
#  'Вчитель математики',
#  'секретарка',
#  'охоронець',
#  'журналістів',
#  'Журналістка',
#  'секретарка',
#  'журналістка',
#  'медсестра',
#  'поета',
#  'Поет',
#  'поет',
#  'поет',
#  'поета',
#  'поета',
#  'лікар',
#  'рок-співак',
#  'театральний режисер',
#  'архітектор',
#  'фахівець із IT',
#  'спортсмен',
#  'художників',
#  'бізнесменів',
#  'письменників',
#  'музикантів',
#  'науковців',
#  'отаман',
#  'Міліціонер',
#  'міліціонер',
#  'міліціонер',
#  'міліціонер',
#  'міліціонер',
#  'президентом австрійського парламенту',
#  'Художник',
#  'кошового отамана',
#  'отамана',
#  'Художники',
#  'розвідники',
#  'вчительку',
#  'дільничний',
#  'селищний голова',
#  'голова',
#  'селищний голова',
#  'дільничного',
#  'селищний голова',
#  'дільничний',
#  'дільничного',
#  'начальник',
#  'менеджер',
#  'Слідчий',
#  'секретаря',
#  'учених',
#  'мікологи',
#  'вчені',
#  'ботанік',
#  'міколог',
#  'судді',
#  'суддів',
#  'судді',
#  'суддею',
#  'судді',
#  'судді',
#  'суддю',
#  'судді',
#  'судді',
#  'судді',
#  'суддів',
#  'суддів',
#  'суддів',
#  'судді',
#  'суддів',
#  'Президенту України',
#  'аналітик',
#  'аналітик',
#  'Політолог',
#  'міністр оборони',
#  'офіцер',
#  'політолог',
#  'чиновників',
#  'силовиків',
#  'Радник Президента',
#  'військові',
#  'дипломати',
#  'радник Президента',
#  'в . о . голови',
#  'голова',
#  'головний суддя',
#  'відповідальний секретар',
#  'режисер',
#  'кошовий отаман',
#  'етнограф',
#  'начальника Генерального штабу',
#  'Головнокомандувача Збройних Сил України',
#  'командувачів видів',
#  'військовослужбовець',
#  'редактор',
#  'журналіст',
#  'спортсменок',
#  'тренера',
#  'майстру спорту',
#  'спортсменка',
#  'судді',
#  'працівник',
#  'робітник',
#  'будівельники',
#  'експерт',
#  'ліквідатор',
#  'експерт із радіаційної безпеки',
#  'експерт',
#  'науковець',
#  'Інженери',
#  'вчених',
#  'стрільців',
#  'гармаші',
#  'стрілець',
#  'отамана',
#  'курінний',
#  'сотником',
#  'отамане',
#  'Старшини',
#  'Сотник',
#  'отаман',
#  'Полковники',
#  'полковники',
#  'полковники',
#  'полковники',
#  'полковники',
#  'поручник',
#  'сотник',
#  'поручником',
#  'отамана',
#  'старшинам',
#  'отамана',
#  'отаман',
#  'ШОКОЛАДНИЦЯ',
#  'Шоколадниці',
#  'священиком',
#  'гладіатора',
#  'священика',
#  'священика',
#  'депутати',
#  'юристи',
#  'податківцям',
#  'НКВД-исти',
#  'Папа',
#  'доктор',
#  'Доктора',
#  'доктором',
#  'доктор',
#  'обсмажувальників',
#  'бариста',
#  'журналіста',
#  'письменника',
#  'публіциста',
#  'редактор',
#  'редактором',
#  'журналістів',
#  'журналіст',
#  'Міський голова',
#  'міський голова',
#  'в . о . начальника',
#  'заступник начальника',
#  'прибиральника',
#  'генерального директора',
#  'гетьман',
#  'коронні гетьмани',
#  'поет',
#  'письменника',
#  'поета',
#  'художника',
#  'поета',
#  'чумаком',
#  'математикові',
#  'вчителів',
#  'Вчителі',
#  'Вчителька математики',
#  'директорами',
#  'чиновниками',
#  'садівницею',
#  'садівників',
#  'перекладач',
#  'перекладачів',
#  'перекладачам',
#  'поетів-авангардистів',
#  'літературознавець',
#  'учитель',
#  'поетеса',
#  'академіка',
#  'лінгвісти',
#  'психологи',
#  'педагоги',
#  'культурологи',
#  'філософи',
#  'письменники',
#  'мовознавці',
#  'учителі',
#  'працівники радіо й телебачення',
#  'урядовці',
#  'тренерам',
#  'Тренери',
#  'Голова громади',
#  'драматургів',
#  'заступник голови райдержадміністрації',
#  'начальник управління фінансів',
#  'начальник відділу освіти',
#  'директори',
#  'заступника голови',
#  'Очільник',
#  'директора',
#  'медичної сестри',
#  'логопеда',
#  'медсестри',
#  'логопеда',
#  'Заступник голови',
#  'Директори',
#  'Механік',
#  'медсестру',
#  'Механік',
#  'лікар',
#  'Механік',
#  'доктор',
#  'механік',
#  'механіка',
#  'механіка',
#  'Суддею',
#  'вчителів',
#  'няньки',
#  'економістів',
#  'етнографів',
#  'істориків',
#  'Поетеса',
#  'поетеса',
#  'поетеса',
#  'Юрист',
#  'ведучій',
#  'служка',
#  'режисера',
#  'наркомом',
#  'головою',
#  'академіком',
#  'академіком',
#  'стрільці',
#  'комісарів',
#  'беркутівця',
#  'беркутівця',
#  'беркутівець',
#  'начальника',
#  'селекціонери',
#  'шахтарем',
#  'шахтар',
#  'священиком',
#  'Таксист',
#  'шахтар',
#  'Шахтареві',
#  'працівників',
#  'директор',
#  'робітника-нелегала',
#  'президента',
#  'Народний депутат',
#  'журналістів',
#  'хліборобів',
#  'журналіста',
#  'редактори',
#  'журналіста',
#  'хліборобів',
#  'журналіста',
#  'журналісти',
#  'ченця',
#  'ченця',
#  'полеміст',
#  'ченців',
#  'інок',
#  'ченця',
#  'ченця',
#  'інока',
#  'Інок',
#  'інок',
#  'Інок',
#  'чернець',
#  'людини-ченця',
#  'ченця',
#  'полеміста',
#  'поет',
#  'поетом',
#  'автор',
#  'поет',
#  'поет',
#  'вчителів',
#  'учителі-ченці',
#  'ігумена',
#  'ректора',
#  'поета',
#  'голови',
#  'митрополита',
#  'Учителі',
#  'учителів-ченців',
#  'вчителі',
#  'ченцям-учителям',
#  'вчителі',
#  'чернець',
#  'ректора',
#  'ректор',
#  'ректору',
#  'іноків',
#  'ректор',
#  'ректор',
#  'ченців',
#  'студентів',
#  'ченців',
#  'ченці',
#  'студентів',
#  'учителі',
#  'учителі-ченці',
#  'ченців',
#  'поет',
#  'чернець',
#  'ієромонах',
#  'ктиторів',
#  'фундаторів',
#  'ченцям',
#  'поет',
#  'поет',
#  'ченців',
#  'ченців-законників',
#  'чернець',
#  'ченцями',
#  'священика',
#  'поет',
#  'ченці',
#  'поет',
#  'ченцях',
#  'ченцях',
#  'чернець',
#  'поет',
#  'іноків',
#  'інокам',
#  'чернець',
#  'голяку-ченцю',
#  'іноків',
#  'інок',
#  'ченцеві',
#  'ченцями',
#  'автор',
#  'інокам',
#  'шафарям',
#  'управителям',
#  'келарів',
#  'іноків',
#  'Іноків',
#  'поет',
#  'Автор',
#  'ченці',
#  'митрополиту',
#  'митрополит',
#  'ченців',
#  'єпископи',
#  'священики',
#  'Автор',
#  'митрополитом',
#  'єпископів',
#  'єпископ',
#  'чернець',
#  'біскуп',
#  'біскупи',
#  'лікаря',
#  'судового слідчого',
#  'учитель історії та географії',
#  'учитель історії та російської мови',
#  'бібліотекар',
#  'старший викладач російської словесності',
#  'помічник інспектора студентів',
#  'викладач російської словесності',
#  'інспектор',
#  'корчмаря',
#  'корчмаря',
#  'корчмаря',
#  'наукові редакторки',
#  'канд . істор . наук',
#  'старша наукова співробітниця',
#  'докторантка відділу соціальної антропології',
#  'голова',
#  'канд . істор . наук',
#  'старша наукова співробітниця',
#  'канд . істор . наук',
#  'старша наукова співробітниця',
#  'письменниця',
#  'докторка історичних наук',
#  'професорка',
#  'канд . істор . наук',
#  'аналітик',
#  'канд . істор . наук',
#  'директор',
#  'керівник',
#  'авторів',
#  'кандидат географічних наук',
#  'члена',
#  'рокером',
#  'заступник міністра внутрішніх справ',
#  'начальник',
#  'заступник міністра',
#  'депутатів',
#  'заступник голови міськвиконкому',
#  'нейробіолог',
#  'служницю',
#  'покоївку',
#  'музики',
#  'сопілкар',
#  'скрипаль',
#  'магістратський писар',
#  'урядник',
#  'писар',
#  'Музики',
#  'писаря',
#  'вчителькою',
#  'хроніст',
#  'князь']

# %%
with open('job_titles/job_title_entities_bruk.txt', 'w') as file:
    for item in job_title_entities_bruk:
        file.write(f"{item}\n")

# %%
import pymorphy3
import pymorphy2

def convert_to_nominative_morph2(words):
    morph = pymorphy2.MorphAnalyzer(lang='uk')
    nominative_words = []

    for word in words:
        parsed = morph.parse(word)[0]
        nominative = parsed.normal_form 
        nominative_words.append(nominative)

    return nominative_words

def convert_to_nominative_morph3(words):
    morph = pymorphy3.MorphAnalyzer(lang='uk')
    nominative_words = []

    for word in words:
            parsed_word = morph.parse(word)[0]
            nominative_word = parsed_word.inflect({'nomn', 'sing'})
            if nominative_word is None:
                nominative_word = parsed_word.normal_form
            else:
                nominative_word = nominative_word.word
            
            nominative_words.append(nominative_word)

    return nominative_words

# %%
def convert_to_nominative(words, pymorphy_v):
    if pymorphy_v == 2:
        morph = pymorphy2.MorphAnalyzer(lang='uk')
    elif pymorphy_v == 3:
        morph = pymorphy3.MorphAnalyzer(lang='uk')
    else:
        print("Invalid pymorphy version")
        return []
    nominative_words = []

    for word in words:
            parsed_word = morph.parse(word)[0]
            nominative_word = parsed_word.normal_form
            nominative_words.append(nominative_word)

    return nominative_words

# %%
job_title_entities_bruk_nouns_3 = convert_to_nominative(job_title_entities_bruk, 3)
job_title_entities_ng_nouns_3 = convert_to_nominative(job_title_entities_ng, 3)

job_title_entities_bruk_dict_3 = dict(zip(job_title_entities_bruk_nouns_3, job_title_entities_bruk))
job_title_entities_ng_dict_3 = dict(zip(job_title_entities_ng_nouns_3, job_title_entities_ng))

#----------------------------------------------------------------------------------------#

job_title_entities_bruk_nouns_2 = convert_to_nominative(job_title_entities_bruk, 2)
job_title_entities_ng_nouns_2 = convert_to_nominative(job_title_entities_ng, 2)

job_title_entities_bruk_dict_2 = dict(zip(job_title_entities_bruk_nouns_2, job_title_entities_bruk))
job_title_entities_ng_dict_2 = dict(zip(job_title_entities_ng_nouns_2, job_title_entities_ng))

# %% [markdown]
# BRUK

# %%
print(len(set(job_title_entities_bruk_nouns_3)))
print(len(set(job_title_entities_bruk_nouns_2)))
# Out:
# 293
# 286

# %%
set(job_title_entities_bruk_nouns_3)-set(job_title_entities_bruk_nouns_2)
# Out:
# {'бариста',
#  'вчителів',
#  'голови',
#  'князів',
#  'кобзар',
#  'королів',
#  'коронні гетьманин',
#  'кутюр’я',
#  'начальників',
#  'поліцаїв',
#  'режисер-постановник',
#  'священиків',
#  'суддів',
#  'художників'}

# %%
set(job_title_entities_bruk_nouns_2)-set(job_title_entities_bruk_nouns_3)
# Out:
# {'барист',
#  'кобзарь',
#  'коронні гетьман',
#  'кутюр’вати',
#  'мікологи',
#  'поліцай',
#  'режисера-постановник'}

# %% [markdown]
# NG

# %%
print(len(set(job_title_entities_ng_nouns_3)))
print(len(set(job_title_entities_ng_nouns_2)))
# Out:
# 348
# 344

# %%
set(job_title_entities_ng_nouns_3)-set(job_title_entities_ng_nouns_2)
# Out:
# {'голови',
#  'головному спеціалісту відділу контролю за використанням та охорони земля',
#  'директорів',
#  'екс-замгубернатора',
#  'замгубернатора',
#  'начальників',
#  'службовець',
#  'суддів'}

# %%
set(job_title_entities_ng_nouns_2)-set(job_title_entities_ng_nouns_3)
# Out:
# {'головному спеціалісту відділу контролю за використанням та охорони земель',
#  'екс-замгубернатор',
#  'замгубернатор',
#  'службовка'}

# %%
# with open('list.txt', 'w') as f:
#     for item in job_title_entities_ng:
#         f.write("%s\n" % item)

# %% [markdown]
# # Using regex

# %%
def find_fems(list_of_words):
    res = []

    patterns = ["нька$", "еса$", "вка$", "иця$", "иня$", "илька$", "елька$", "стка$", "йка$", "анка$", "иса$", "чка$", "рка$", "сестра$", "тка$", "жка$", "менка$", "$держ"]

    for x in list_of_words:
        x = x.lower()
        if len(x.split(" ")) > 1:
            for y in x.split(" "):
                if any(re.search(pattern, y) for pattern in patterns):
                    print(x)
                    res.append(x)
                    break
        else:
            if any(re.search(pattern, x) for pattern in patterns):
                print(x)
                res.append(x)

    return res

# %%
bruk_res = find_fems(job_title_entities_bruk_nouns)
# Out:
# актриса
# вихователька
# продавчиня
# лікарка
# вчителька
# вчителька
# викладачка
# лікарка
# секретарка
# психологиня
# мовознавиця
# кандидатка філологічних наука
# викладачка
# вчителька
# співачка
# секретарка
# журналістка
# секретарка
# журналістка
# медсестра
# вчителька
# спортсменка
# спортсменка
# шоколадниця
# шоколадниця
# вчителька математика
# садівниця
# поетеса
# медсестра
# медсестра
# нянька
# поетеса
# поетеса
# поетеса
# служка
# наукові редакторка
# старша наукова співробітниця
# докторантка відділу соціальної антропологія
# старша наукова співробітниця
# старша наукова співробітниця
# письменниця
# докторка історичних наука
# професорка
# служниця
# покоївка
# вчителька

# %%
print("------ FOR bruk DATASET ---------")

print("Кількість фемінітивів у JOB TITLES класах:", len(bruk_res))
print("кількість таких унікальних значень(без дублів):", len(set(bruk_res)))

print("Відношення фемінітивів до усіх JOB TITLE класів: {:.1f}%".format(len(bruk_res)*100/len(job_title_entities_bruk)))
# Out:
# ------ FOR bruk DATASET ---------
# Кількість фемінітивів у JOB TITLES класах: 46
# кількість таких унікальних значень(без дублів): 28
# Відношення фемінітивів до усіх JOB TITLE класів: 7.2%

# %%
ng_res = find_fems(job_title_entities_ng_nouns)
# Out:
# голови митниця
# підприємиця
# підприємиця
# власниця
# власниця
# приватною підприємиця
# підприємиця
# підприємиця
# підприємниця
# підприємиця
# лаборантка
# співзасновниця
# співзасновниця
# екс-чиновниця
# чиновниця
# екс-антимонопольниця
# керівниця
# заступниця
# службовка
# співзасновниця
# чиновниця
# податківка
# податківка
# засновниця
# власниця
# засновниця
# журналістка
# журналістка

# %%
print("------ FOR ng DATASET ---------")

print("Кількість фемінітивів у JOB TITLES класах:", len(ng_res))
print("кількість таких унікальних значень(без дублів):", len(set(ng_res)))

print("Відношення фемінітивів до усіх JOB TITLE класів: {:.1f}%".format(len(ng_res)*100/len(job_title_entities_ng)))
# Out:
# ------ FOR ng DATASET ---------
# Кількість фемінітивів у JOB TITLES класах: 28
# кількість таких унікальних значень(без дублів): 16
# Відношення фемінітивів до усіх JOB TITLE класів: 2.1%

# %% [markdown]
# # With feminine nouns dictionary

# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
def read_fem_dict(url, dict_file_name):

    json_file = {}

    if os.path.exists(dict_file_name):
        with open(dict_file_name, 'r', encoding='utf-8') as f:
            try:
                json_file = json.load(f)
            except json.JSONDecodeError:
                json_file = {}

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        html = response.content
    else:
        print(f"Не вдалося отримати сторінку, код статусу: {response.status_code}")

    soup = BeautifulSoup(html, 'html.parser')

    dictionary = {}

    paragraphs = soup.find_all('p')

    dict_part = paragraphs[4:-1]
    print(dict_part)
    for para in dict_part:
        text = para.get_text().strip()
        
        if "–" in text:
            item = text.split("–")
            masculine = item[0]
            feminine = item[1]
            masculine = masculine.strip()
            feminine = feminine.strip()

            dictionary[masculine] = feminine

    
    json_file.update(dictionary)

    with open(dict_file_name, 'w', encoding='utf-8') as f:
        json.dump(json_file, f, ensure_ascii=False, indent=4)

    print("saved dict for url:", url)

# %%
letters = ['a', 'b', 'v', 'g', 'd', 'e', 'ye', 'zh', 'z', 'i', 'k', 'l', 'm', 'n', 'o', 'p', 'r', 's', 't', 'u', 'f', 'h', 'cz', 'ch', 'sh', 'shh', 'yu', 'ya']

# %%
json_file = "fem_dictionary.json"

for letter in letters:
    url = f"https://gendergid.org.ua/{letter}/"
    read_fem_dict(url, json_file)
# Out:
# [<p>язичник – язичниця</p>, <p>японець – японка</p>, <p>японіст – японістка</p>, <p>ясновидець – ясновидиця</p>, <p>яхтсмен – яхтсменка</p>, <p>язичник – язичниця</p>, <p>японець – японка</p>, <p>японіст – японістка</p>, <p>ясновидець – ясновидиця</p>, <p>яхтсмен – яхтсменка</p>, <p><a href="https://www.usaid.gov/uk/ukraine" rel="nofollow"><img alt="" class="alignnone wp-image-842" height="35" src="https://gendergid.org.ua/wp-content/uploads/2021/08/usaid2-300x96.png" width="110"/></a><a href="https://internews.in.ua/uk/media-program-in-ukraine/" rel="nofollow"><img alt="" class="alignnone wp-image-841" height="34" src="https://gendergid.org.ua/wp-content/uploads/2021/08/usaid1-300x96.png" width="106"/></a><a href="http://volynpressclub.org.ua/" rel="nofollow"><img alt="" class="alignnone wp-image-840" height="37" src="https://gendergid.org.ua/wp-content/uploads/2021/08/usaid-1-300x96.png" width="115"/></a><img alt="" class="alignnone wp-image-5481" height="43" src="https://gendergid.org.ua/wp-content/uploads/2024/01/zobrazhennya_viber_2024-01-08_12-09-17-362-300x78.png" width="165"/></p>, <p><a href="https://www.usaid.gov/uk/ukraine" rel="nofollow"><img alt="" class="alignnone wp-image-842" height="38" src="https://gendergid.org.ua/wp-content/uploads/2021/08/usaid2-300x96.png" width="120"/></a><a href="https://internews.in.ua/uk/media-program-in-ukraine/" rel="nofollow"><img alt="" class="alignnone wp-image-841" height="39" src="https://gendergid.org.ua/wp-content/uploads/2021/08/usaid1-300x96.png" width="121"/></a><a href="http://volynpressclub.org.ua/" rel="nofollow"><img alt="" class="alignnone wp-image-840" height="40" src="https://gendergid.org.ua/wp-content/uploads/2021/08/usaid-1-300x96.png" width="124"/><img alt="" class="alignnone wp-image-5481" height="34" src="https://gendergid.org.ua/wp-content/uploads/2024/01/zobrazhennya_viber_2024-01-08_12-09-17-362-300x78.png" width="130"/></a></p>, <p><a href="https://www.facebook.com/gendergiude"><img alt="" class="alignnones wp-image-823" height="19" src="https://gendergid.org.ua/wp-content/uploads/2021/05/fac258.png" width="19"/></a><span style="color: #000000;"><a href="https://www.facebook.com/gendergiude" style="color: #000000!important;">Facebook</a></span></p>]
# saved dict for url: https://gendergid.org.ua/ya/

# %%
dict_file_name = 'fem_dictionary.json'

with open(dict_file_name, 'r', encoding='utf-8') as f:
    dictionary = json.load(f)

print(list(dictionary.values()))
# Out:
# ['абітурієнтка', 'абонентка', 'аборигенка', 'абстракціоністка', 'авантюристка', 'автоматниця', 'автомобілістка', 'авторка', 'агентка', 'агітаторка', 'агностикиня', 'агрономка', 'адвокатка', 'адміністраторка', 'адресантка', 'академікиня (пані академік)', 'академістка', 'аквалангістка', 'акварелістка', 'акомпаніаторка', 'акордеоністка', 'акробатка', 'активістка', 'акторка', 'акушерка', 'акціонерка', 'алергологиня', 'алжирка', 'альбіноска', 'альпіністка', 'альтруїстка', 'амбасадорка', 'американка', 'аналітикиня', 'анархістка', 'анестезіологиня', 'англійка', 'аніматорка', 'антагоністка', 'антисемітка', 'антропологиня', 'апологетка', 'аптекарка', 'арабка', 'аравійка', 'арбітерка, арбітриня', 'аргентинка', 'арештантка', 'аристократка', 'арійка', 'артистка', 'арфістка', 'архаїстка', 'археологиня', 'архівістка', 'архітекторка', 'асистентка', 'аскетка', 'аспірантка', 'астрологиня', 'астронавтка', 'атеїстка', 'аудиторка', 'афганка', 'аферистка', 'африканка', 'багатійка (багач', 'базарниця', 'байкарка', 'байкерка', 'баламутка', 'балетмейстерка', 'бандитка', 'бандуристка', 'банкірка', 'барабанщиця', 'бар’єристка', 'барменка / -вуменка', 'баронеса', 'баскетболістка', 'баяністка', 'безлюдниця', 'безпритульна', 'безробітна', 'белетристка', 'біатлоністка', 'бібліотекарка', 'бігунка', 'біженка', 'бізнесвумен', 'біологиня', 'бісексуалка', 'благодійниця', 'блогерка', 'бійчиня', 'боксерка', 'борчиня', 'боржниця', 'боягузка', 'бранка', 'брехунка', 'бригадирка', 'британка', 'брокерка', 'буддистка', 'будівельниця', 'букмекерка', 'бунтарка', 'бунтівниця', 'бухгалтерка', 'бюрократка', 'вантажниця', 'вартова', 'ватниця', 'вахтерка', 'вболівальниця', 'вдова, вдовиця', 'веганка', 'вегетаріанка', 'ведуча', 'велосипедистка', 'вербувальниця', 'вередунка', 'верстатниця', 'верхолазка', 'вершниця', 'веслувальниця', 'ветеранка', 'виборниця', 'вигадниця', 'вигнанка', 'вигодонабувачка', 'видавниця, видавчиня', 'видобувачка', 'визвольниця (визволителька)', 'викладачка', 'виконавиця', 'виконувачка (н-д, обов’язків)', 'викривачка', 'вимагачка', 'винахідниця', 'виноробка', 'винуватиця', 'випробувальниця', 'випускниця', 'витівниця', 'вихованка', 'вихователька', 'вишивальниця', 'відвідувачка', 'відлюдниця', 'відмінниця', 'відповідачка', 'відправниця', 'відьма', 'візажистка', 'військова', 'військовослужбовиця', 'вільнодумка, вільнодумиця', 'віолончелістка', 'віртуозка', 'вітрянка', 'віщунка', 'вкладниця', 'власниця', 'водійка', 'водолазка', 'вокалістка', 'волейболістка', 'володарка', 'волонтерка', 'ворожбитка (ворожка)', 'воротарка', 'воячка', 'вродливиця', 'в(у)чена', 'вчителька', 'газетярка', 'галеристка', 'гандболістка', 'гарнтка', 'гастролерка', 'генетикиня', 'пані генерал', 'геодезистка', 'геологиня', 'германістка', 'героїня', 'герцогиня', 'гетеросексуалка', 'гідеса', 'гімназистка', 'гімнастка', 'гінекологиня', 'гіпнотизерка', 'гостя', 'гітаристка', 'глядачка', 'говорунка', 'годувальниця', 'гомосексуалка', 'гомофобка', 'гонщиця', 'горянка', 'госпітальєрка', 'господиня', 'грабіжниця', 'гравчиня', 'графиня', 'грішниця', 'громадянка', 'гросмейстерка', 'губернаторка', 'гуманістка', 'гумористка', 'гурманка', 'дантистка', 'дачниця', 'двірниця', 'дворянка', 'дебютантка', 'дегустаторка', 'деканка', 'декламаторка', 'декораторка', 'делегатка', 'демократка', 'депутатка', 'державниця', 'дерматологиня', 'десантниця', 'дефектологиня', 'джазменка', 'дзвонарка', 'дзюдоїстка', 'дивачка', 'диверсантка', 'дизайнерка', 'дикторка', 'дикунка', 'дилетантка', 'дипломатка', 'дипломантка', 'директорка', 'диригентка', 'дисидентка', 'диспетчерка', 'диспутантка', 'діалектологиня', 'ді-джейка', 'дієтологиня', 'дізнавачка', 'дільнича', 'діячка', 'добровольця', 'добродійка', 'доброчиниця', 'добрячка', 'довірителька', 'доглядальниця', 'доглядачка', 'докторка', 'докторантка', 'документалістка', 'домохазяйка', 'донорка', 'дописувачка', 'доповідачка', 'дослідниця', 'дотепниця', 'доцентка', 'драматургиня', 'дресирувальниця', 'подруга', 'друкарка', 'дуалістка', 'дублерка', 'дурисвітка', 'духівниця', 'е ...

# %%
def find_fems_with_dict(list_of_words):
    res = []

    list_of_fems = list(dictionary.values())

    for x in list_of_words:
        if x in list_of_fems:
            res.append(x)

    return res

# %%
ng_res_dict = find_fems_with_dict(job_title_entities_ng_nouns)

# %%
ng_res_dict
# Out:
# ['підприємиця',
#  'підприємиця',
#  'власниця',
#  'власниця',
#  'підприємиця',
#  'підприємиця',
#  'підприємиця',
#  'лаборантка',
#  'співзасновниця',
#  'співзасновниця',
#  'чиновниця',
#  'керівниця',
#  'заступниця',
#  'співзасновниця',
#  'чиновниця',
#  'засновниця',
#  'власниця',
#  'засновниця',
#  'журналістка',
#  'журналістка']

# %%
print("------ FOR ng DATASET ---------")

print("Кількість фемінітивів у JOB TITLES класах:", len(ng_res_dict))
print("кількість таких унікальних значень(без дублів):", len(set(ng_res_dict)))

print("Відношення фемінітивів до усіх JOB TITLE класів: {:.1f}%".format(len(ng_res_dict)*100/len(job_title_entities_ng)))
# Out:
# ------ FOR ng DATASET ---------
# Кількість фемінітивів у JOB TITLES класах: 20
# кількість таких унікальних значень(без дублів): 9
# Відношення фемінітивів до усіх JOB TITLE класів: 1.5%

# %%
bruk_res_dict = find_fems_with_dict(job_title_entities_bruk_nouns)

# %%
bruk_res_dict
# Out:
# ['вихователька',
#  'продавчиня',
#  'лікарка',
#  'вчителька',
#  'вчителька',
#  'викладачка',
#  'лікарка',
#  'психологиня',
#  'викладачка',
#  'вчителька',
#  'співачка',
#  'журналістка',
#  'журналістка',
#  'вчителька',
#  'спортсменка',
#  'спортсменка',
#  'садівниця',
#  'письменниця',
#  'професорка',
#  'служниця',
#  'вчителька']

# %%
print("------ FOR bruk DATASET ---------")

print("Кількість фемінітивів у JOB TITLES класах:", len(bruk_res_dict))
print("кількість таких унікальних значень(без дублів):", len(set(bruk_res_dict)))

print("Відношення фемінітивів до усіх JOB TITLE класів: {:.1f}%".format(len(bruk_res_dict)*100/len(job_title_entities_bruk)))
# Out:
# ------ FOR bruk DATASET ---------
# Кількість фемінітивів у JOB TITLES класах: 21
# кількість таких унікальних значень(без дублів): 13
# Відношення фемінітивів до усіх JOB TITLE класів: 3.3%

# %% [markdown]
# ## Read uk-dict

# %%
import pandas as pd

df = pd.read_csv('/Users/linndfors/study/diploma/dict_uk/out/dict_corp_lt.txt', delimiter=' ', header=None, names=['word', 'lemma', 'grammar'])

# %%
df.head()
# Out:
#   word lemma                              grammar
# 0    а     а                           conj:coord
# 1    а     а                                 intj
# 2    а     а                                 part
# 3   АА    АА                         noninfl:abbr
# 4   АА    АА  noun:inanim:p:v_naz:nv:ns:abbr:prop

# %%
pers = 'Тамара Матяш'
part_of_name = pers.split(" ")

# %%
for part in part_of_name:
    print(df[df['word']==part])
# Out:
#            word   lemma                       grammar
# 5733272  Тамара  Тамара  noun:anim:f:v_naz:prop:fname
# 5733286  Тамара  Тамара  noun:inanim:f:v_naz:prop:geo
#           word  lemma                          grammar
# 2919125  Матяш  Матяш     noun:anim:m:v_naz:prop:lname
# 2919135  Матяш  Матяш  noun:anim:f:v_naz:nv:prop:lname
# 2919136  Матяш  Матяш  noun:anim:f:v_rod:nv:prop:lname
# 2919137  Матяш  Матяш  noun:anim:f:v_dav:nv:prop:lname
# 2919138  Матяш  Матяш  noun:anim:f:v_zna:nv:prop:lname
# 2919139  Матяш  Матяш  noun:anim:f:v_oru:nv:prop:lname
# 2919140  Матяш  Матяш  noun:anim:f:v_mis:nv:prop:lname
# 2919141  Матяш  Матяш  noun:anim:f:v_kly:nv:prop:lname

# %%
df[df['word']=='Тамара']
# Out:
#            word   lemma                       grammar
# 5733272  Тамара  Тамара  noun:anim:f:v_naz:prop:fname
# 5733286  Тамара  Тамара  noun:inanim:f:v_naz:prop:geo

# %%
def find_person_entities(directory):
    ann_files = find_ann_files(directory)
    job_title_entities = []

    for ann_file in ann_files:
        with open(ann_file, "r", encoding="utf-8") as ann_f:
            for ann_l in ann_f:
                ann_row = ann_l.split("\t")
                
                try: 
                    if ann_row[1] == 'PERS':
                        job_title_entities.append(ann_row[4].strip("\n"))
                except Exception as e:
                    continue
                    # print("Error with line:", ann_row)

    return job_title_entities

# %%
pers_entities_bruk = find_person_entities('../ner_for_fem/data/bruk')

# %%
len(pers_entities_bruk)
# Out:
# 4415

# %%
pers_entities_bruk
# Out:
# ['Каппело',
#  'Тібо Куртуа',
#  'Міральяса',
#  'Орігі',
#  'Хорхе Луїса Пінто',
#  'Діас',
#  'Руїс',
#  'Буффона',
#  'Пранделлі',
#  'Антоніо Кассано',
#  'Вісенте дель Боске',
#  'Хорхе Сампаолі',
#  'Іван Руснак',
#  'Кажаном',
#  'Аристофана',
#  'Сократ',
#  'Аліна',
#  'Аліна',
#  'Аліна',
#  'Аліна',
#  'Аліна',
#  'Аліна',
#  'Аліна',
#  'Аристофана',
#  'Аліна',
#  'Кіріко',
#  'Кінга',
#  'Аліна',
#  'Аліна',
#  'Аліна',
#  'Аліна',
#  'Аліну',
#  'Аліна',
#  'Аліна',
#  'Кажан',
#  'Аліна',
#  'Бог',
#  'Аліна',
#  'Алінині',
#  'Аліною',
#  'Кажан',
#  'Аліна',
#  'Аліна',
#  'Аліна',
#  'Аліни',
#  'Кажан',
#  'Аліна',
#  'Аліну',
#  'Аліна',
#  'Ірина',
#  'Аліна',
#  'Ірина',
#  'Боже',
#  'Аліна',
#  'Аліна',
#  'Аліна',
#  'Малий',
#  'Господь',
#  'Рокошу',
#  'Ян Щасний Гербурт',
#  'Іван Мазепа',
#  'Рокошу Зебжидовського',
#  'Павлусь',
#  'Гербуртів',
#  'Михайло',
#  'Божої',
#  'Гербурту',
#  'Гербуртова',
#  'Божа',
#  'фон Трієра',
#  'Кіфера Сазерленда',
#  'Дарини',
#  'фон Трієра',
#  'фон-Трієрівського',
#  'Антона Санченка',
#  'Бог',
#  'Бог',
#  'Бог',
#  'Бога',
#  'Бог',
#  'Сталін',
#  'Аліна',
#  'Аліна',
#  'Кажана',
#  'Аліна',
#  'Данило',
#  'Алінко',
#  'Кажан',
#  'Марту',
#  'Аліна',
#  'Кажан',
#  'Алінко',
#  'Аліна',
#  'Марту',
#  'Аліна',
#  'Аліна',
#  'Аліна',
#  'Кажана',
#  'Аліна',
#  'Аліна',
#  'Аліна',
#  'Аліна',
#  'Алінко',
#  'Алінко',
#  'Кажан',
#  'Алінину',
#  'Алінко',
#  'Аліна',
#  'Д . Пилипчук',
#  'Б . Лепкого',
#  'Ілліч',
#  'Михайла Грушевського',
#  'Христина',
#  'Христина',
#  'Христина',
#  'Христині',
#  'Христина',
#  'Наталочка',
#  'Наталочка',
#  'Орися',
#  'Наталочка',
#  'Орися',
#  'Наталочка',
#  'Орисі',
#  'Наталочка',
#  'Окарина',
#  'Наталочки',
#  'Наталочка',
#  'Наталочку',
#  'Наталочка',
#  'Наталочку',
#  'Наталочка',
#  'Наталочка',
#  'Орися',
#  'Наталочці',
#  'Кий',
#  'Наталочка',
#  'Добрада',
#  'Наталочка',
#  'Кий',
#  'Щек',
#  'Хорив',
#  'Либідь',
#  'Наталочка',
#  'Наталочка',
#  'Кий',
#  'Наталочка',
#  'Наталочка',
#  'Кий',
#  'Кий',
#  'Кия',
#  'Наталочка',
#  'Кий',
#  'Наталочка',
#  'Наталочка',
#  'Наталочка',
#  'Щек',
#  'Хорив',
#  'Либеді',
#  'Наталочка',
#  'Орисі',
#  'Орися',
#  'Д . Лебедем',
#  'Д . Лебедя',
#  'Іван Підгорський',
#  'Іван Куць',
#  'Еллісон',
#  'Еллісона',
#  'Бейнбрідж',
#  'Кістяковський',
#  'Роберт',
#  'Всевишнім',
#  'Ґроувза',
#  'Оппенгеймер',
#  'Еллісон',
#  'Господи',
#  'Еллісон',
#  'Господь',
#  'Верховної Особи',
#  'Господи',
#  'Господь',
#  'Донна',
#  'Господи',
#  'Василь Нагірний',
#  'Андрієм Кіщуком',
#  'Кіблер',
#  'Кіблер',
#  'Карла',
#  'Кіблера',
#  'Василь Нагірний',
#  'Олександр Брензей',
#  'Тетяна Щербина',
#  'Катерина Дегтяр',
#  'Інна Березіна',
#  'Валентина Лайтер',
#  'Галина Ярошевська',
#  'Наталія Оцишена',
#  'Олександр Віштаченко',
#  'Світован',
#  'Луї Віттона',
#  'Армані',
#  'Ігор Індило',
#  'Халедом Саїдом',
#  'Мохаммедом Буазізі',
#  'Небесний Отець',
#  'Бога',
#  'Божого',
#  'Небесного Отця',
#  'Господь',
#  'Богові',
#  'Господь',
#  'Бог',
#  'Христос',
#  'Богом',
#  'Бог',
#  'Христос',
#  'В . І . Перебийніс',
#  'М . М . Пещак',
#  'М . П . Муравицької',
#  'Т . О . Грязнухіної',
#  'Н . П . Дарчук',
#  'Н . Ф . Клименко',
#  'Л . І . Комарової',
#  'В . І . Критської',
#  'Т . К . Пуздирєвої',
#  'Л . В . Орлової',
#  'Л . А . Алексієнко',
#  'Т . І . Недозим',
#  'В . І . Критської',
#  'Л . В . Орлової',
#  'Т . К . Пуздирєвої',
#  'Ю . В . Романюк',
#  'Т . І . Недозим',
#  'Н . Ф . Клименко',
#  'Стефанія',
#  'Магдалина',
#  'Божої Матері',
#  'Юрко',
#  'Юрко',
#  'Роман',
#  'Левко',
#  'Петром',
#  'Левко',
#  'Роман',
#  'Юрко',
#  'Іванку',
#  'Петро',
#  'Петро',
#  'Петро',
#  'Юрко',
#  'Іванки',
#  'Іванку',
#  'Юрко',
#  'Яковом',
#  'Петром',
#  'Яків',
#  'Якова',
#  'Яків',
#  'Якова',
#  'Петро',
#  'Юрія',
#  'Юрія',
#  'Господні',
#  'Романові',
#  'Кохановська',
#  'Оленки',
#  'Оленка',
#  'Аґнєшка',
#  'Оленку',
#  'Роман',
#  'Романів',
#  'Аґнєшки',
#  'Оленка',
#  'Романові',
#  'Аґнєшка Кохановська',
#  'Роман',
#  'Олена',
#  'Роман',
#  'Гаврилко',
#  'Олеся',
#  'Малгосиної',
#  'Корнель',
#  'Олесь',
#  'Геродот',
#  'Сальомеї',
#  'Корнеля',
#  'Корнелю',
#  'Олеся',
#  'Нуся',
#  'Корнеля',
#  'Салькою',
#  'Геродот',
#  'Русина',
#  'Сальомея',
#  'Яхве',
#  'Бога',
#  'Мученика',
#  'Пилата',
#  'Варавві',
#  'Ісусові',
#  'Корнель',
#  'Давида',
#  'Корнель',
#  'Сальомеєю',
#  'Бога',
#  'Корнель',
#  'Сальомеї',
#  'Олесь',
#  'Нусі',
#  'Мученик',
#  'Яхве',
#  'Корнеля',
#  'Сальомею',
#  'Геродот',
#  'Сальомеї',
#  'Корнель',
#  'Геродот',
#  'Олесь',
#  'Корнель',
#  'Шамрай',
#  'Олесь',
#  'Олесь',
#  'Геродот',
#  'Корнель',
#  'Сковороди',
#  'Олесь',
#  'Геродотові',
#  'Богові',
#  'Геродот',
#  'Господньої',
#  'Бог',
#  'Бога',
#  'Олесю',
#  'Погодіна',
#  'Костюшка',
#  'Брусілова',
#  'Юрко Сербин',
#  'Тарновецький',
#  'Чемеринський',
#  'Нуся',
#  'Юрко Сербин',
#  'Павло Сербин',
#  'Юрків',
#  'Сербин',
#  'Віка Петрова',
#  'Аллочку',
#  'Славіка',
#  'Аллусю',
#  'Пресвята Богородице',
#  'Наталя',
#  'Славік',
#  'Славік',
#  'Зойка',
#  'Щур',
#  'Наталі',
#  'Сашко Щур',
#  'Наталі',
#  'Наталі',
#  'Наталя',
#  'Наталя',
#  'Славік',
#  'Віка Петрова',
#  'Йоостою',
#  'Віка',
#  'Віки',
#  'Славіка',
#  'Славік',
#  'Віку',
#  'Яковом',
#  'Гамлетів',
#  'Колріджа',
#  'Вордсворта',
#  'Мелвіла',
#  'Фітцджеральда',
#  'Артюр Рембо',
#  'Селінджер',
#  'Еней',
#  'Кароліна Кужвій',
#  'Кароліна Кужвій',
#  'Кароліна',
#  'Кароліна',
#  'Кароліна',
#  'Кароліна',
#  'Кароліна',
#  'Роберта',
#  'Кароліна',
#  'Божий',
#  'Господь',
#  'Ноя',
#  'Господь',
#  'Божий',
#  'Син',
#  'Батько',
#  'Матвія',
#  'Христос',
#  'Вільямові Міллеру',
#  'Даниїла',
#  'Міллер',
#  'Міллер',
#  'Христа',
#  'Міллер',
#  'Богу',
#  'Чарльз Лонг',
#  'Еліо Бланко',
#  'Малий',
#  'Сусанну',
#  'Сусанна',
#  'Малий',
#  'П’ятниця',
#  'Малий',
#  'Малий',
#  'Ірма',
#  'Малого',
#  'Ірму',
#  'Ірма',
#  'Сусаннину',
#  'Ірмою',
#  'Малим',
#  'Малий',
#  'Ірма',
#  'Сусанна',
#  'Сусанна',
#  'Сніговика',
#  'Сніговика',
#  'Сусанна',
#  'Малого',
#  'Сніговиковим',
#  'Сніговик',
#  'Сніговик',
#  'Кварк',
#  'Сніговик',
#  'Сніговик',
#  'Сусанна',
#  'Малий',
#  'Ірма',
#  'Сніговика',
#  'Сніговикових',
#  'Сусанна',
#  'Сніговика',
#  'Сніговик',
#  'Сніговика',
#  'Ілля Бунька',
#  'Устимко',
#  'Івасиків',
#  'Настунь',
#  'Гапочок',
#  'Мати Божа',
#  'Устимка',
#  'Івасика',
#  'Настуню',
#  'Гапочку',
#  'Устимко',
#  'Мартин',
#  'Устимко',
#  'Боженьку',
#  'Котові',
#  'Кіт',
#  'Устимко',
#  'Амфібрахієві',
#  'Амфібрахій',
#  'Устимко',
#  'Амфібрахієм',
#  'Амфібрахій',
#  'Устимко',
#  'Амфібрахій',
#  'Каньовського',
#  'Амфібрахієм',
#  'Устимко',
#  'Амфібрахія',
#  'Наталя',
#  'Сергій Корнієнко',
#  'Сергія Корнієнка',
#  'Гоголь',
#  'Гоголь',
#  'Христа',
#  'Гоголь',
#  'М . Бердяєв',
#  'Хлєстакова',
#  'Копєйкін',
#  'Брєжнєва',
#  'Ноздрьов',
#  'Квіткою-Основ’яненком',
#  'Гоголь',
#  'Сергій Аксаков',
#  'Гоголя',
#  'Квітки-Основ’яненка',
#  'Гоголь',
#  'Гоголя',
#  'Квітка',
#  'Гоголь',
#  'Квітки',
#  'Квітка',
#  'Гоголем',
#  'Квітка',
#  'Гоголя',
#  'Хлєстакова',
#  'Хлєстакова',
#  'Хлєстакову',
#  'Гоголь',
#  'Гоголь',
#  'Чичикова',
#  'Гулівером',
#  'Гоголь',
#  'Чичиков',
#  'Манілов',
#  'Д . С . Ліхачов',
#  'Манілов',
#  'Чичикова',
#  'Микола',
#  'Манілов',
#  'Чичикова',
#  'Манілов',
#  'Миколу',
#  'Манілов',
#  'Д . С . Ліхачов',
#  'Манілова',
#  'Манілова',
#  'Гоголя',
#  'Гоголь',
#  'Ноздрьова',
#  'Тютчева',
#  'Гоголя',
#  'Ноздрьов',
#  'Коробочки',
#  'Ноздрьов',
#  'Достоєвського',
#  'Гоголя',
#  'Шевченка',
#  'Божим',
#  'Ковальова',
#  'Бог',
#  'Хреста',
#  'Бог',
#  'Юрія',
#  'Марині',
#  'Марина',
#  'Юрія',
#  'Мариною',
#  'Марина',
#  'Марину',
#  'Юрій',
#  'Юрій',
#  'Інга',
#  'Марина',
#  'Юрій',
#  'Марини',
#  'Марині',
#  'Юра',
#  'Марина',
#  'Інга',
#  'Юрій',
#  'Юрій',
#  'Інга',
#  'Марина',
#  'Інгу',
#  'Інга',
#  'Ганну Нетребко',
#  'Марина',
#  'Інга',
#  'Марина',
#  'Інгу',
#  'Марина',
#  'Юрій',
#  'Інгу',
#  'Інга',
#  'Юриною',
#  'Марина',
#  'Юрій',
#  'Інзі',
#  'Марині',
#  'Юра',
#  'Марина',
#  'Інгою',
#  'Інга',
#  'Потап',
#  'Діда Мороза',
#  'Денис',
#  'Потап',
#  'Потапом',
#  'Потап',
#  'Потап',
#  'Денис',
#  'Потапенко',
#  'Денис',
#  'Матвія',
#  'Потап',
#  'Денис',
#  'Ірою',
#  'Транквіліоном',
#  'Іра',
#  'Іра',
#  'Ірою',
#  'Доля',
#  'Долі',
#  'Мавки',
#  'Долю',
#  'Долю',
#  'Долі',
#  'Доля',
#  'Долі',
#  'Доля',
#  'Доля',
#  'Доля',
#  'Смерть',
#  'Доля',
#  'Доля',
#  'Смерть',
#  'Долю',
#  'Доля',
#  'Устимко',
#  'Амфібрахій',
#  'Амфібрахію',
#  'Амфібрахій',
#  'Амфібрахій',
#  'Амфібрахій',
#  'Амфібрахій',
#  'Амфібрахія',
#  'Устимко',
#  'Сагайдачного',
#  'Дорошенка',
#  'Ляща',
#  'Конецьпольського',
#  'Бог',
#  'Гриця',
#  'Паляниці',
#  'Гната Паляницю',
#  'Паляниць',
#  'Амфібрахій',
#  'Паляниці',
#  'Одарки',
#  'Божа',
#  'Ліцінарові',
#  'Амфібрахій',
#  'Амфібрахій',
#  'Устимко',
#  'Амфібрахій',
#  'Соню',
#  'Соні',
#  'Соня',
#  'Соня',
#  'Соні',
#  'Соня',
#  'Соні',
#  'Соні',
#  'Соня',
#  'Соня',
#  'Соня',
#  'Соня',
#  'Соня',
#  'Соня',
#  'Соня',
#  'Соня',
#  'Соня',
#  'Коля',
#  'Соня',
#  'Соню',
#  'Соня',
#  'Соня',
#  'Соні',
#  'Соні',
#  'Сонина',
#  'Соні',
#  'Соня',
#  'Соня',
#  'Соня',
#  'Галя',
#  'Тонька',
#  'Галя',
#  'Тонька',
#  'Галі',
#  'Галя',
#  'Галя',
#  'Галина Дорош',
#  'Галі',
#  'Галина Дорош',
#  'Галі',
#  'Галина Таназіївна',
#  'Соколова',
#  'Галини Дорош',
#  'Галя',
#  'Галину Дорош',
#  'Галя',
#  'Галина Дорош',
#  'Тоньці',
#  'Антоніна',
#  'Галя',
#  'Галину Дорош',
#  'Галя',
#  'Галі',
#  'Тоньку',
#  'Антоніна',
#  'Галина Дорош',
#  'Галі',
#  'Галі',
#  'Галина Дорош',
#  'Льва Толстого',
#  'Романа Мархоліа',
#  'Толстой',
#  'Шекспіра',
#  'Федір Протасов',
#  'Машу',
#  'Федя',
#  'Протасов',
#  'Федя',
#  'Толстого',
#  'Феді',
#  'Михайла Романова',
#  'Олексія Богдановича',
#  'Феді',
#  'Толстой',
#  'Роман Мархоліа',
#  'Толстовський',
#  'Остап Ступка',
#  'Віктора Кареніна',
#  'Наталія Сумська',
#  'Кареніна',
#  'Протасова',
#  'Тетяна Міхіна',
#  'Машу',
#  'Протасова',
#  'Лесь Задніпровський',
#  'Абрезков',
#  'Олег Стальчук',
#  'Слідчий',
#  'Геній',
#  'Тінь',
#  'Федя',
#  'Феді Протасова',
#  'Мархоліа',
#  'Толстого',
#  'Габр',
#  'Габр',
#  'Габр',
#  'Габр',
#  'Габр',
#  'Габр',
#  'Габр',
#  'Габр',
#  'Габр',
#  'Й . Сталін',
#  'Рафаель',
#  'Микола Хвильовий',
#  'Михайль Семенко',
#  "Валер'ян Поліщук",
#  'Яків Савченко',
#  'Павло Тичина',
#  'Павло Савченко',
#  'Яків Савченко',
#  'Олекса Слісаренко',
#  'Дмитро Загул',
#  'Микола Терещенко',
#  'Музагет',
#  'Аполлона',
#  'Діоніса',
#  'Юрій Іванів-Меженко',
#  'Філіппо Марінетті',
#  'Гійом Аполлінер',
#  'Володимир Маяковський',
#  'Ігор Северянін',
#  'Велімир Хлєбніков',
#  'Михайль Семенко',
#  'Пабло Пікассо',
#  'Пабло Пікассо',
#  'Михайль Семенко',
#  'Олекса Слісаренко',
#  'Гео Шкурупій',
#  'Володимир Ярошенко',
#  'Анатолій Петрицький',
#  'Слісаренко',
#  'Михайль Семенко',
#  'Гео Шкурупій',
#  'Михайло Яловий',
#  'Олекса Слісаренко',
#  'Гео Коляда',
#  'Андрій Чужий',
#  'Лесь Курбас',
#  'Михайль Семенко',
#  'Володимира Винниченка',
#  'Василь Еллан-Блакитний',
#  'Кость Гордієнко',
#  'Іван Дніпровський',
#  'Олександр Довженко',
#  'Майк Йогансен',
#  'Олександр Копиленко',
#  'Іван Кулик',
#  'Володимир Сосюра',
#  'Павло Тичина',
#  'Микола Хвильовий',
#  'Василь Еллан-Блакитний',
#  'Микола Хвильовий',
#  'Микола Хвильовий',
#  'Михайло Яловий',
#  'Олесь Досвітній',
#  'Микола Бажан',
#  'Олександр Довженко',
#  'Григорій Епік',
#  'Майк Йогансен',
#  'Григорій Коцюба',
#  'Олександр Копиленко',
#  'Микола Куліш',
#  'Аркадій Любченко',
#  'Юрій Смолич',
#  'Володимир Сосюра',
#  'Павло Тичина',
#  'Сергій Пилипенко',
#  'Дмитро Бедзик',
#  'Володимир Гжицький',
#  'Андрій Головко',
#  'Наталя Забіла',
#  'Василь Минко',
#  'Іван Сенченко',
#  'Павло Усенко',
#  "Валер'ян Підмогильний",
#  'Михайло Івченко',
#  'Борис Антоненко-Давидович',
#  'Григорій Косинка',
#  'Євген Плужник',
#  'Сергій Воскрекасенко',
#  'Іван Гончаренко',
#  'Ярослав Гримайло',
#  'Сава Голованівський',
#  'Борис Коваленко',
#  'Петро Колесник',
#  'Олександр Корнійчук',
#  'Степан Крижанівський',
#  'Терень Масенко',
#  'Леонід Первомайський',
#  'Леонід Смілянський',
#  'Анатолій Шиян',
#  'Василь Десняк',
#  'Іван Ле',
#  'Микола Терещенко',
#  'Юрій Яновський',
#  'Фелікс Якубовський',
#  'Володимир Ярошенко',
#  'Володимир Гжицький',
#  'Микола Марфієвич',
#  'Федір Малицький',
#  'Василь Бобинський',
#  'Олесь Бабій',
#  'Роман Купчинський',
#  'Юрій Шкрумеляк',
#  'Левко Лепкий',
#  'Митуса',
#  'Богдан-Ігор Антонич',
#  'Богдан Кравців',
#  'Антонич',
#  'Юрій Дараган',
#  'Леонід Мосендз',
#  'Євген Маланюк',
#  'Олекса Стефанович',
#  'Олег Ольжич',
#  'Олена Теліга',
#  'Галя Мазуренко',
#  'Оксана Лятуринська',
#  'Іван Ірлявський',
#  'Дмитро Донцов',
#  'Євген Маланюк',
#  'Наталя Лівицька-Холодна',
#  'Леонід Мосендз',
#  'Павло Чирський',
#  'Павло Зайцев',
#  'Юрій Липа',
#  'Михайло Рудницький',
#  'Льва Троцького',
#  'Т . Бразельтон',
#  'Г . Шаффер',
#  'П . Емерсон',
#  'Ф . Гальтоном',
#  'Д . Кембелл',
#  'Д . Фіське',
#  'С . Стівенс',
#  'Іра',
#  'Ірине',
#  'Ірі',
#  'Іриного',
#  'Ірою',
#  'Ернст Теодор Амадей Гофман',
#  'Едґар По',
#  'Месмера',
#  'Жан-Мартен Шарко',
#  'П’єра Жане',
#  'Ойґена Бльойлєра',
#  'Йозефа Броєра',
#  'Шарко',
#  'Зиґмунда Фройда',
#  'Берту Папенгайм',
#  'Йозефа Броєра',
#  'Броєром',
#  'Берта',
#  'Анна О',
#  'Фройдова',
#  'Еммі фон Н',
#  'Фройдом',
#  'Фройд',
#  'Ґюстава Ейфеля',
#  'Жан-Люк',
#  'Марина',
#  'Боже',
#  'Еллен',
#  'Левченко',
#  'Андрій',
#  'Левченко',
#  'Нещерет',
#  'Левченка',
#  'Люба',
#  'Андрій',
#  'Савича',
#  'Андрій',
#  'Левченко',
#  'Люба',
#  'Андрій',
#  'Люба',
#  'Люба',
#  'Андрій',
#  'Левченко',
#  'Любу',
#  'Левченко',
#  'Любу',
#  'Сомова',
#  'Андрій',
#  'Нещеретом',
#  'Андрій',
#  'Андрій',
#  'Дяка',
#  'Андрій',
#  'Андрій',
#  'Дяка',
#  'Дяче',
#  'Дяка',
#  'Андрій',
#  'Андрія',
#  'Андрій',
#  'Андрій',
#  'Андрій',
#  'Марічка',
#  'Марічка',
#  'Андрій',
#  'Андрій',
#  'Андрія',
#  'Михайлов',
#  'Михайлова',
#  'Михайлов',
#  'Олена',
#  'ВІТЕР',
#  'Вітер',
#  'Вітер',
#  'Анна',
#  'Август',
#  'Лачплесиса',
#  'Лачплесис',
#  'Лачплесис',
#  'Лачплесис',
#  'Чорний Лицар-хрестоносець',
#  'Лачплесиса',
#  'Геродотові',
#  'Володимир Бондаренко',
#  'Володимир Бондаренко',
#  'Бондаренка',
#  'Володимир Бондаренко',
#  'Володимира Бондаренка',
#  'Зінаїда',
#  'Василь Соколенко',
#  'Олеся Статива',
#  'Людмила Власенко',
#  'Віктора Швидкого',
#  'Френка Андервуда',
#  'Валентину Вітеру',
#  'Володимира Бондаря',
#  'Миколою Романюком',
#  'Валерія Трикоша',
#  'Дмитро Дубняк',
#  'Володимир Гунчик',
#  'Микола Євтушин',
#  'Володимир Бондар',
#  'Володимира Нальковича',
#  'Віталій Тарасюк',
#  'Андрій Харлампович',
#  'Адама Харламповича',
#  'Валентина Муковоза',
#  'Валентина Вітера',
#  'Валентин Вітер',
#  'Валентин Вітер',
#  'Валентин Вітер',
#  'Валентину Вітеру',
#  'Микола Романюк',
#  'Вітера',
#  'Олександр Пирожик',
#  'Пирожика',
#  'Данильчук',
#  'Андріані',
#  'Андріана',
#  'Андріана',
#  'Бог',
#  'Андріана',
#  'Андріані',
#  'Андріана',
#  'Андріана',
#  'Андріані',
#  'Андріана',
#  ...]

# %%
test_pers = set(pers_entities_bruk[:30])

# %%
# import re

# tag_string = "noun:anim:f:v_naz:prop:fname"

# match = re.search(r'\bf\b', tag_string)

# if match:
#     print("Found:", match.group())
# else:
#     print("Not found")
# Out:
# Found: f

# %%
df[df['word'] == 'Аліна']
# Out:
#         word  lemma                       grammar
# 95002  Аліна  Аліна  noun:anim:f:v_naz:prop:fname

# %%
for pers in test_pers:
    part_of_name = pers.split(" ")
    for part in part_of_name:
        try:
            filtered_df = df[df['word'] == part]
            if not filtered_df.empty:
                grammar_pers = filtered_df['grammar'].iloc[0]
                # print(part)

                match_f = re.search(r'\bf\b', grammar_pers)
                match_m = re.search(r'\bm\b', grammar_pers)

                if match_f:
                    print("Found female:", part)
                    is_female = 1
                if match_m:
                    print("Found male:", part)
                    is_female = 0
                else:
                    print("Not found any gender property:", part)
            else:
                grammar_pers = None 
                print("No matches found for:", part)
        except Exception as e:
            print("error", e)
# Out:
# Found male: Діас
# No matches found for: Пранделлі
# Found male: Вісенте
# Not found any gender property: дель
# Found male: Боске
# No matches found for: Кіріко
# Found male: Кінга
# Found female: Аліна
# Not found any gender property: Аліна
# No matches found for: Міральяса
# No matches found for: Кажаном
# Found male: Антоніо
# No matches found for: Кассано
# No matches found for: Каппело
# Found male: Руїс
# Found male: Іван
# Found male: Руснак
# Found male: Аристофана
# Found male: Хорхе
# No matches found for: Сампаолі
# No matches found for: Орігі
# Found male: Буффона
# Found male: Сократ
# Found male: Тібо
# Found male: Куртуа
# Found male: Хорхе
# Found male: Луїса
# Found male: Пінто
