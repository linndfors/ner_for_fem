# %%
import os
import re
from shutil import copyfile

def extract_entities(txt_file, ann_file):
    # Read the txt file
    with open(txt_file, 'r', encoding='utf-8') as f:
        txt_content = f.read()
    
    # Read the ann file
    with open(ann_file, 'r', encoding='utf-8') as f:
        ann_lines = f.readlines()
    
    # Extract the entities and their ranges from the ann file
    entities = []
    for line in ann_lines:
        parts = line.split("\t")
        entity_type = parts[1]
        start, end = map(int, parts[2].split())
        entity_text = txt_content[start:end]
        entities.append((entity_type, entity_text, start, end))
    
    # Sort entities by their start position in the text to maintain order
    entities.sort(key=lambda x: x[2])
    
    # Create the modified txt content with only the entities
    modified_txt_content = " ".join([entity[1] for entity in entities])

    return modified_txt_content, entities

def update_ann_file(ann_file, entities, modified_txt_content):
    # Create a new .ann file with updated indices
    new_ann_lines = []
    new_start = 0
    
    for entity_type, entity_text, old_start, old_end in entities:
        # Find the new start and end indices based on the modified text
        new_end = new_start + len(entity_text)
        new_ann_lines.append(f"T{len(new_ann_lines)+1}\t{entity_type} {new_start} {new_end}\t{entity_text}\n")
        new_start = new_end + 1  # add a space between entities in the modified text
    
    return new_ann_lines

def process_files(txt_file, ann_file, output_txt_dir, output_ann_dir):
    # Extract entities and modified text
    modified_txt_content, entities = extract_entities(txt_file, ann_file)
    
    # Create the new .txt filename in the output directory
    output_txt_file = os.path.join(output_txt_dir, os.path.basename(txt_file))
    with open(output_txt_file, 'w', encoding='utf-8') as f:
        f.write(modified_txt_content)

    # Update the .ann file and save it
    new_ann_lines = update_ann_file(ann_file, entities, modified_txt_content)
    output_ann_file = os.path.join(output_ann_dir, os.path.basename(ann_file))
    with open(output_ann_file, 'w', encoding='utf-8') as f:
        f.writelines(new_ann_lines)

def main(input_txt_dir, input_ann_dir, output_txt_dir, output_ann_dir):
    # Ensure output directories exist
    os.makedirs(output_txt_dir, exist_ok=True)
    os.makedirs(output_ann_dir, exist_ok=True)
    
    # Iterate through .txt files and process the corresponding .ann files
    for txt_filename in os.listdir(input_txt_dir):
        try:
            if txt_filename.endswith('.txt'):
                txt_file = os.path.join(input_txt_dir, txt_filename)
                ann_file = os.path.join(input_ann_dir, txt_filename.replace('.txt', '.ann'))
                
                # Check if the corresponding .ann file exists
                if os.path.exists(ann_file):
                    process_files(txt_file, ann_file, output_txt_dir, output_ann_dir)
                    print(f"Processed: {txt_filename}")
                else:
                    print(f"Warning: No corresponding .ann file for {txt_filename}")
        except Exception as e:
            print(e, "::::", txt_file)

# %%
len("начальниця управління масових і спортивних заходів департаменту громадської безпеки ")
# Out:
# 84

# %%
# Define your input and output directories
input_txt_dir = '/Users/linndfors/study/diploma/ner_for_fem/data/DATA_FOR_BALANCED_NER/ng_changed'  # Replace with the path to your .txt files directory
input_ann_dir = '/Users/linndfors/study/diploma/ner_for_fem/data/DATA_FOR_BALANCED_NER/ng_changed'  # Replace with the path to your .ann files directory
output_txt_dir = '/Users/linndfors/study/diploma/ner_for_fem/src/ng_changed'  # Replace with the path to your output .txt files directory
output_ann_dir = '/Users/linndfors/study/diploma/ner_for_fem/src/ng_changed'  # Replace with the path to your output .ann files directory

# Run the main function
main(input_txt_dir, input_ann_dir, output_txt_dir, output_ann_dir)
# Out:
# Processed: 8e66b8ea5086_1.txt
# Processed: 26c531a355cc_1.txt
# Processed: 09e1dccb8839_1.txt
# Processed: 3dfca2b9b104_1.txt
# Processed: 4bdc94abaa1c_1.txt
# Processed: cc9eda5dc1f3_1.txt
# Processed: 3b285211209c_1.txt
# Processed: 78153c6d7c59_1.txt
# Processed: 07c51f631d18_1.txt
# Processed: fe12a985f7cd_1.txt
# Processed: d6ca19c4065e_1.txt
# Processed: 87deabcc8f95_1.txt
# Processed: 5a43160b965d_1.txt
# Processed: d7e523681acc_1.txt
# Processed: 258d2fd0d2fe_1.txt
# Processed: 52a055482925_1.txt
# Processed: 29ee46b3128e_1.txt
# Processed: 9690987f7b71_1.txt
# Processed: 5e407e3ddb68_1.txt
# Processed: 5d3d7e0d5bae_1.txt
# Processed: 4ea65724096f_1.txt
# Processed: 47713afd9490_1.txt
# Processed: 1b68c2c76541_1.txt
# Processed: 2980d5c34788_1.txt
# Processed: 8c6db2873e45_1.txt
# Processed: 19a095d6ed15_1.txt
# Processed: 236f916f3d6f_1.txt
# Processed: 46b3a16d4154_1.txt
# Processed: fc3221dac69d_1.txt
# Processed: 16fb31bf76b8_1.txt
# Processed: 104263660695_1.txt
# Processed: c97bff36f45a_1.txt
# Processed: 0f0e96425eed_1.txt
# Processed: 517bca22990a_1.txt
# Processed: 02634352df22_1.txt
# Processed: 6350e46219ca_1.txt
# Processed: ca414599779c_1.txt
# Processed: 76b9b07172fb_1.txt
# Processed: 66f7109b4b72_1.txt
# Processed: 1a15fc79575f_1.txt
# Processed: 7d5bd98c3363_1.txt
# Processed: 989b35bbc2b6_1.txt
# Processed: 16a112c13847_1.txt
# Processed: ba4d4c8da29b_1.txt
# Processed: 0f94c5cc63c3_1.txt
# Processed: d84580a3bacf_1.txt
# Processed: 30933a298472_1.txt
# Processed: 03d075bafb84_1.txt
# Processed: 39c7437146fd_1.txt
# Processed: 996f3a16780e_1.txt
# Processed: 7ab185008967_1.txt
# Processed: 8806c823dee8_1.txt
# Processed: cbf21c99c504_1.txt
# Processed: a6b3166e4d3b_1.txt
# Processed: 0e31947e4561_1.txt
# Processed: 2d2e9cf66e5b_1.txt
# Processed: 30856acf29fc_1.txt
# Processed: ba4204adf371_1.txt
# Processed: 39c1d99f468f_1.txt
# Processed: c07e05e53013_1.txt
# Processed: 4de429586136_1.txt
# Processed: c3156652dba3_1.txt
# Processed: 798252fda0ab_1.txt
# Processed: e2e03aba8da3_1.txt
# Processed: 8ae216cd6d99_1.txt
# Processed: 1044724b1e84_1.txt
# Processed: 4ac82fdf4d4d_1.txt
# Processed: d81632a877d7_1.txt
# Processed: 63711262f9fb_1.txt
# Processed: 1e8b049462e1_1.txt
# Processed: 003d28360166_1.txt
# Processed: f62160cb3ef6_1.txt
# Processed: 605d2142ccad_1.txt
# Processed: ac7d3bf88e39_1.txt
# Processed: 06d7009e4925_1.txt
# Processed: de4c2d20b24b_1.txt
# Processed: b9ea4aa52bae_1.txt
# Processed: 5e33850771e3_1.txt
# Processed: 0e6b8eb14491_1.txt
# Processed: e0c33f29a3ae_1.txt
# Processed: e19e41e16752_1.txt
# Processed: 08c0799d889a_1.txt
# Processed: 3fdf22393022_1.txt
# Processed: 41cf54503fc6_1.txt
# Processed: c446d7d1cea2_1.txt
# Processed: 535022e2bdd2_1.txt
# Processed: c1ddc42c47fb_1.txt
# Processed: 757fc6f23e18_1.txt
# Processed: 75e21fe4f3b7_1.txt
# Processed: 54a45ec4929b_1.txt
# Processed: 8936d7a04255_1.txt
# Processed: 7248ab4edfe9_1.txt
# Processed: d509463360e2_1.txt
# Processed: bbc5330abbdc_1.txt
# Processed: cb7958ff386e_1.txt
# Processed: 7d59bb5fe9f5_1.txt
# Processed: 01cfbeca9827_1.txt
# Processed: 1e9389b05e86_1.txt
# Processed: 0f9884d8a5e1_1.txt
# Processed: 510661e4d39d_1.txt
# Processed: 36aa8022709f_1.txt
# Processed: 6b71dda907fe_1.txt
# Processed: f82ca27cb935_1.txt
# Processed: b0163b57e788_1.txt
# Processed: 39544dbbe184_1.txt
# Processed: a854e880d075_1.txt
# Processed: 883e1bd852d8_1.txt
# Processed: f4119f5f8406_1.txt
# Processed: 163e835b7aef_1.txt
# Processed: 7f9631dbc39d_1.txt
# Processed: f2653a1e387d_1.txt
# Processed: 348b96a54914_1.txt
# Processed: b217b90e209d_1.txt
# Processed: 9835fd136cb4_1.txt
# Processed: bf6104a5e8cc_1.txt
# Processed: 06826af4579d_1.txt
# Processed: 369c3876ae3d_1.txt
# Processed: ac13bf912fcb_1.txt
# Processed: b859478153e4_1.txt
# Processed: 6ada9307320e_1.txt
# Processed: 1c48b2f37af3_1.txt
# Processed: c9e6ab501a7e_1.txt
# Processed: 605667093f7b_1.txt
# Processed: b3e92d56950f_1.txt
# Processed: cffa0e3aa90f_1.txt
# Processed: 290f12765b32_1.txt
# Processed: 872cdd84eee4_1.txt
# Processed: fa2b54229991_1.txt
# Processed: f5e3415a3653_1.txt
# Processed: c5930ba45ebe_1.txt
# Processed: 25df43bd3fc5_1.txt
# Processed: d13ee85bbf5c_1.txt
# Processed: 12ca40b4ecac_1.txt
# Processed: 1ce0dee84a4d_1.txt
# Processed: a04af354c8db_1.txt
# Processed: 00b1a798bebf_1.txt
# Processed: 176e63516fab_1.txt
# Processed: d080aa19c4bd_1.txt
# Processed: 04b2cf6b449e_1.txt
# Processed: 23fed9919583_1.txt
# Processed: 59a9444d5c2d_1.txt
# Processed: 7faf035614c1_1.txt
# Processed: 6f6281133248_1.txt
# Processed: d4a86a1591b4_1.txt
# Processed: b991b2d46f85_1.txt
# Processed: 5ae61df96054_1.txt
# Processed: 0050229d8534_1.txt
# Processed: 5111063957b7_1.txt
# Processed: 1adfefe0e695_1.txt
# Processed: f50037706d0a_1.txt
# Processed: c09661af0a89_1.txt
# Processed: b645c9653d72_1.txt
# Processed: 452ba42e97ec_1.txt
# Processed: e54ada2b9649_1.txt
# Processed: 3e94fe6e9161_1.txt
# Processed: 432e298a1354_1.txt
# Processed: 540d36b4fe1c_1.txt
# Processed: 2ff4fbe3fcc4_1.txt
# Processed: 18dbbac93012_1.txt
# Processed: 76cfe1c0a0b6_1.txt
# Processed: 61267204736d_1.txt
# Processed: e32c3effa79e_1.txt
# Processed: 1257e7421756_1.txt
# Processed: b4fe41ad2268_1.txt
# Processed: 3b4ea1813b99_1.txt
# Processed: e96b3ae1908b_1.txt
# Processed: c650874a1e16_1.txt
# Processed: ff85f24f2204_1.txt
# Processed: 45ce670b36e1_1.txt
# Processed: 33b6963bc554_1.txt
# Processed: a767be7c3792_1.txt
# Processed: 7ff7b6cfbbc2_1.txt
# Processed: eed5beaf4033_1.txt
# Processed: a9d2c035032d_1.txt
# Processed: 03b52358982b_1.txt
# Processed: f8ce14d569d1_1.txt
# Processed: 97c7987b8f9c_1.txt
# Processed: ab299615a1ce_1.txt
# Processed: 4f2aecdde4c8_1.txt
# Processed: 6d47a8c4d755_1.txt
# Processed: 7d19fba564ad_1.txt
# Processed: 2850ba499aea_1.txt
# Processed: c2a04d86bfb8_1.txt
# Processed: ce52c670e720_1.txt
# Processed: 8098d69d861f_1.txt
# Processed: bed0c1b62024_1.txt
# Processed: 62127c82f7cd_1.txt
# Processed: aae1500a7f12_1.txt
# Processed: 5658ff392f11_1.txt
# Processed: 94c633b4d39a_1.txt
# Processed: 64d0d60bba23_1.txt
# Processed: 7e6a2bdcfd1c_1.txt
# Processed: 937ae8974dd6_1.txt
# Processed: c49d24717658_1.txt
# Processed: 35a759d5871f_1.txt
# Processed: 3e21f62b9a2f_1.txt
# Processed: 6920ac746f54_1.txt
# Processed: a56a7edf7859_1.txt
# Processed: 150446f83aa2_1.txt
# Processed: fd7413336034_1.txt
# Processed: bd76ed4df58f_1.txt
# Processed: f342f88df1c8_1.txt
# Processed: db4996034aa6_1.txt
# Processed: 789ba2b89a05_1.txt
# Processed: 5a4b4498fe83_1.txt
# Processed: 7cf7a5aacb51_1.txt
# Processed: d1d4639dbadd_1.txt
# Processed: 02bebf42e010_1.txt
# Processed: f5475c5dbfc9_1.txt
# Processed: 8b3ec884f52d_1.txt
# Processed: bf276ac58f0f_1.txt
# Processed: 9452af41a134_1.txt
# Processed: 7982679365fb_1.txt
# Processed: 00edded01d7f_1.txt
# Processed: a4bdacf739df_1.txt
# Processed: 64bbab373f73_1.txt
# Processed: b060489eff8f_1.txt
# Processed: 9a51afb8d050_1.txt
# Processed: 037bb6843538_1.txt
# Processed: 0e5456794c26_1.txt
# Processed: b72e7e33e081_1.txt
# Processed: 73eb785ac9bb_1.txt
# Processed: a4eee55da896_1.txt
# Processed: b2541ea8cb83_1.txt
# Processed: 4fa4b01c6204_1.txt
# Processed: 5f0dd24186aa_1.txt
# Processed: 7eae7aa310d7_1.txt
# Processed: 86c78648f86f_1.txt
# Processed: d084adea3ae8_1.txt
# Processed: 3eef4bd7fc75_1.txt
# Processed: cb8dd5ea2542_1.txt
# Processed: 3d437460799f_1.txt
# Processed: cf79fc17c020_1.txt
# Processed: 69dd300fd706_1.txt
# Processed: ab66959f7440_1.txt
# Processed: 4671f9337340_1.txt
# Processed: bf3f1e807703_1.txt
# Processed: e37120a0aa66_1.txt
# Processed: 17f81040ab50_1.txt
# Processed: fc5b5a35776f_1.txt
# Processed: 386f07b6aca3_1.txt
# Processed: 5de8e21df21b_1.txt
# Processed: c8944932e85f_1.txt
# Processed: 82e415f0dd48_1.txt
# Processed: 357039d66ab7_1.txt
# Processed: 372677bde8c8_1.txt
# Processed: 8f5d434373e2_1.txt
# Processed: 4e486c879cf1_1.txt
# Processed: 65a4cc6e3723_1.txt
# Processed: 2c14409069b7_1.txt
# Processed: bdb88360d4a8_1.txt
# Processed: e0c4e3168c81_1.txt
# Processed: 1c3c6180ad96_1.txt
# Processed: 8e1267225acc_1.txt
# Processed: aeabc0bd5724_1.txt
# Processed: e6f68e10e0e4_1.txt
# Processed: 860e4c9353fc_1.txt
# Processed: 2d37a2344b1e_1.txt
# Processed: 315a7f9491ac_1.txt
# Processed: 1c3533ec1df3_1.txt
# Processed: 05b89d1a90bf_1.txt
# Processed: cdc9c08df7ac_1.txt
# Processed: c99d1ad0cc3c_1.txt
# Processed: 3b570ac3116b_1.txt
# Processed: 816a89664813_1.txt
# Processed: 67b6f23997c5_1.txt
# Processed: 79ccf625bc94_1.txt
# Processed: 521b5669bca6_1.txt
# Processed: 5d7350e7d539_1.txt
# Processed: 19ebc4aa5eb5_1.txt
# Processed: 9893f2c9cae9_1.txt
# Processed: 9c264bd5a100_1.txt
# Processed: 3aa7c6a81ddd_1.txt
# Processed: d15b83fd32bd_1.txt

# %%
# Define your input and output directories
input_txt_dir = '/Users/linndfors/study/diploma/ner_for_fem/data/DATA_FOR_BALANCED_NER/bruk_changed'  # Replace with the path to your .txt files directory
input_ann_dir = '/Users/linndfors/study/diploma/ner_for_fem/data/DATA_FOR_BALANCED_NER/bruk_changed'  # Replace with the path to your .ann files directory
output_txt_dir = '/Users/linndfors/study/diploma/ner_for_fem/src/bruk_changed'  # Replace with the path to your output .txt files directory
output_ann_dir = '/Users/linndfors/study/diploma/ner_for_fem/src/bruk_changed'  # Replace with the path to your output .ann files directory

# Run the main function
main(input_txt_dir, input_ann_dir, output_txt_dir, output_ann_dir)
# Out:
# Processed: 09d6a57532b6_1.txt
# Processed: bf4968831cc7_1.txt
# Processed: bc755153f4f7_1.txt
# Processed: 1ed3fef56c8f_1.txt
# Processed: dac0de834f47_1.txt
# Processed: 27a1722d517c_1.txt
# Processed: 5a0aedfe0f5d_1.txt
# Processed: dc1202fd9850_1.txt
# Processed: 4b1efc986bb8_1.txt
# Processed: b576ac602665_1.txt
# Processed: e3c7064319e0_1.txt
# Processed: 10a2da5c514c_1.txt
# Processed: efc2665e4bed_1.txt
# Processed: 2fc890744f7c_1.txt
# Processed: e5e76a8efa0f_1.txt
# Processed: 17fbae84faea_1.txt
# Processed: 15238b87db03_1.txt
# Processed: b019e9b8d51d_1.txt
# Processed: d07dfb774c28_1.txt
# Processed: 5710814a4a84_1.txt
# Processed: f495f41dfa02_1.txt
# list index out of range :::: /Users/linndfors/study/diploma/ner_for_fem/data/DATA_FOR_BALANCED_NER/bruk_changed/17d3d678df81_1.txt
# Processed: e023d6d6f1a3_1.txt
# Processed: 548f66f38090_1.txt
# Processed: a196488351f6_1.txt
# Processed: c0c436cc9cb6_1.txt
# Processed: 232be2c6b5c2_1.txt
# Processed: 1c325fde9ed4_1.txt
# Processed: 2298b6b41bec_1.txt
# Processed: a1a77d3d5b33_1.txt
# Processed: 9df8bcf8e17e_1.txt
# Processed: 1c37d315923c_1.txt
# Processed: ea3fab248fbe_1.txt
# Processed: 5e10574a909c_1.txt
# Processed: b381bc7842b1_1.txt
# Processed: 766e1942f398_1.txt
# Processed: 71a651d2dbec_1.txt
# Processed: c0f24f5d70e3_1.txt
# Processed: 0046ebeff13e_1.txt
# Processed: 0b962bee49bc_1.txt
# Processed: b87576a7425a_1.txt
# Processed: 6e4853575182_1.txt
# Processed: 326978d2c58c_1.txt
# Processed: 7b7daaeb9d7d_1.txt
# Processed: 561acef3f531_1.txt
# Processed: 132368095bab_1.txt
# Processed: 937c38344fdf_1.txt
# Processed: 3ba7ca929d68_1.txt
# Processed: b84c8a869b51_1.txt
# Processed: c28168a23912_1.txt
# Processed: 38603af07530_1.txt
# Processed: 92d38b895fa4_1.txt
# Processed: f9a926049262_1.txt
# Processed: dc25535e13d7_1.txt
# Processed: 13e0cb95075a_1.txt
# Processed: 755c890a06fb_1.txt
# Processed: 3f4bafb349ae_1.txt
# Processed: 85622bc925dc_1.txt
# Processed: e1dbe335e762_1.txt
# Processed: e1d8841dcc68_1.txt
# Processed: 74a7e2a340dd_1.txt
# Processed: 9c0774172f73_1.txt
# Processed: b09a79bafe6c_1.txt
# Processed: 647a3f078f3f_1.txt
# Processed: d08ea0bbac66_1.txt
# Processed: c375246adb0a_1.txt
# Processed: 06d78909a7ab_1.txt
# Processed: 0ac5140eb732_1.txt
# Processed: f958ce8bb461_1.txt
# Processed: e0493ec8466b_1.txt
# Processed: f4136bfda19a_1.txt
# Processed: f161f5134505_1.txt
# Processed: 7b2c9399fee9_1.txt
# Processed: 5085bb95b51a_1.txt
# Processed: ef1b6bd52747_1.txt
# Processed: 164940c99b86_1.txt
# Processed: c6807dbff658_1.txt
# Processed: 9494fddb0caa_1.txt
# Processed: fad2422a7bf3_1.txt
# Processed: 066ec5f0dea6_1.txt
# Processed: d30e0fb50f0f_1.txt
# Processed: f5bb37569413_1.txt
# Processed: 5a75a46fecdf_1.txt
# Processed: 6b60e6fb3d78_1.txt
# Processed: e21ddb9efb07_1.txt
# Processed: 1448663b16b2_1.txt
# Processed: dcbb9ddb4aaa_1.txt
# Processed: ff069c11e13d_1.txt
# Processed: 87ae82667e2a_1.txt
# Processed: bd86f567c746_1.txt
# Processed: d530671576f8_1.txt
# Processed: 52049bc57554_1.txt
# Processed: f4ca58272dbf_1.txt
# Processed: fc8f156aa82b_1.txt
# Processed: 6b5d4229b548_1.txt
# Processed: 66395d7c394b_1.txt
# Processed: e8188caa466c_1.txt
# Processed: 0d902430768c_1.txt
# Processed: bdda872d3ef9_1.txt
# Processed: b3c847570902_1.txt
# Processed: 9fbfe077a27a_1.txt
# Processed: aad4dce361f1_1.txt
# Processed: 710044df1fe0_1.txt
# Processed: c3402705f448_1.txt
# Processed: 91024fa21059_1.txt
# Processed: 5207847a2e1d_1.txt
# Processed: 624df1293f3d_1.txt
# Processed: e9061171da9d_1.txt
# Processed: 1484f7813550_1.txt
# Processed: 257fca043205_1.txt
# Processed: 2846bf1d66a8_1.txt
# Processed: 547ce681ada8_1.txt
# Processed: 5764f733fff2_1.txt
# Processed: e010e86e436c_1.txt
# Processed: d3d5522aa52e_1.txt
# Processed: fabc18a7d8fd_1.txt
# Processed: 2cc21b456aad_1.txt
# Processed: 8951230172d0_1.txt
# Processed: 46ae77c0ec97_1.txt
# Processed: a616672f4a8b_1.txt
# Processed: b987128d15d3_1.txt
# Processed: a487d1895726_1.txt
# Processed: 47eb526780b0_1.txt
# Processed: d81f996d0ab8_1.txt
# Processed: 9d4b90129d10_1.txt
# Processed: 8cc49a8b2d76_1.txt
# Processed: cad2484c0cc8_1.txt
# Processed: 79812f4abec1_1.txt
# Processed: 18ec3aea7ed7_1.txt
# Processed: d3669729136c_1.txt
# Processed: cee02d4c030f_1.txt
